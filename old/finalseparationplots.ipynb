# %% [markdown]
# ## Determining the separation on the sky for the matches between pristine and other catalogues

# %% [markdown]
# Making a plot of the separation in the matching for each of the Pristine X other catalogue. Then performing a cut based on the approximately log-normal median and median absolute deviation, such that all the matches are within the median +/- 3*MAD. The Intersection of all these catalogues is then compiled and written to a new table. The catalogues are 2MASS, SDSS, DESI Legacy, Gaia, CFIS/UNIONS, Pan-STARRS dr1 & dr3, and, of course, Pristine.

# %%
import pandas as pd
import numpy as np
from astropy.io import fits
import matplotlib.pyplot as plt
from statsmodels import robust
from scipy.stats import mode

# %% [markdown]
# Measuring the speed at which these files download

# %%
# %%time
hdu = fits.open('/arc/home/aydanmckay/phottable-x-lamost-pre-edit.fits')
data = hdu[1].data
# Out:
# CPU times: user 287 ms, sys: 57.8 ms, total: 345 ms
# Wall time: 431 ms

# %%
len(data['ra'])
# Out:
# 1000653

# %% [markdown]
# #### Separation Parameters:
# angDist_1: Separation between LAMOST dr8 and Gaia edr3 \
# Separation_1: Separation between Pristine and Gaia+LAMOST \
# angDist_2: Separation between Pristine and 2MASS \
# Separation_1a: Separation between 2MASS and Pristine+Gaia+LAMOST \
# Separation_2: Separation between Pristine and CFIS/UNIONS \
# Separation_1b: Separation between CFIS and Pristine+Gaia+LAMOST+2MASS \
# Separation_2a: Separation between Pristine and Pan-STARRS dr3 \
# Separation_1c: Separation between Pan-STARRS dr3 and Pristine+Gaia+LAMOST+2MASS+CFIS \
# Separation_2b: Separation between Pristine and DESI Legacy \
# Separation_1d: Separation between Legacy and Pristine+Gaia+LAMOST+2MASS+CFIS+Pan3 \
# angDist_1a: Separation between Pristine and SDSS Photobjs dr17 \
# Separation_1e: Separation between SDSS and Pristine+Gaia+LAMOST+2MASS+CFIS+Pan3+DESI \
# angDist_2a: Separation between Pristine and Pan-STARRS dr1 \
# Separation: Separation between Pan-STARRS dr1 and Pristine+Gaia+LAMOST+2MASS+CFIS+Pan3+DESI+SDSS

# %%
# Creating lists to save the medians and MADs for making cuts later
seps = [['angDist_2','2MASS'],['angDist_1a','SDSS'],['Separation_2b','DESI Legacy'],['Separation_1','Gaia+LAMOST'],['Separation_2','CFIS'],['angDist_2a','Pan-STARRS DR1']]
mads = np.zeros((6,1))
meds = np.zeros((6,1))

# %% [markdown]
# Plotting the separation between the matched sources.

# %%
for it,sep in enumerate(seps):    
    # Creating the histogram of the separation values
    histo = plt.hist(data[sep[0]],bins=100)
    plt.title('Angular Separation [\"] of Pristine and '+sep[1])
    # Determining the median
    median = np.nanmedian(data[sep[0]])
    meds[it] += median
    plt.axvline(median,c='k',label='Median')
    # Determining the Median Absolute Deviation
    mad = robust.mad(data[sep[0]][np.isnan(data[sep[0]]) == False])
    mads[it] += mad
    plt.axvline(median+3*mad,c='k',linestyle='dashed',label=r'Median+3*MAD')
    # Determining the empirically derived mode
    empmode = 2.5*np.nanmedian(data[sep[0]]) - 1.5*np.nanmean(data[sep[0]])
    plt.axvline(empmode,c='r',linestyle='dashed',label='Empirical Mode')
    # Determining the actual mode
    dermode = mode(data[sep[0]][np.isnan(data[sep[0]]) == False])
    plt.axvline(dermode[0],c='r',label='Mode')
    plt.legend(fancybox=True)
    plt.show()

# %% [markdown]
# So it looks like we're missing a parameter from the log normal distribution in order to properly fit the data. It could also be a result of how the fit is matched to the bins. I tried the bin middles and that seemed more off than the bin ends, so theres some research to be done there. \
# We don't want to be curve fitting I guess, just want to use the raw statistics and obtain the median and the MAD. \
# Some of the calculated modes seemed to be quite off as clearly the mode wouldn't be a zero. Therefore we'll stick with the median and that cut for now.

# %%
mdata = data.copy()

# %%
for it,sep in enumerate(seps):
    mask = (mdata[sep[0]] < (meds[it]+3*mads[it])) | (np.isnan(mdata[sep[0]]) == True)
    mdata = mdata[mask]

# %% [markdown]
# So now we're dealing with datafi as the table and we can remove every entry that doesn't have a separation in any table.

# %% [markdown]
# Making the intersection mask

# %%
# Making sure that a value exists for every one of the matches
mask = (np.isnan(mdata[seps[0][0]]) == False) & (np.isnan(mdata[seps[1][0]]) == False) & (np.isnan(mdata[seps[2][0]]) == False) & \
       (np.isnan(mdata[seps[3][0]]) == False) & (np.isnan(mdata[seps[4][0]]) == False) & (np.isnan(mdata[seps[5][0]]) == False) & \
       (mdata['snrg'] > 20) & (mdata['TEFF_PASTEL'] > 0) & (mdata['TEFF_PASTEL'] < 60000) & (mdata['FEH_PASTEL'] > -5) & \
       (mdata['parallax_over_error'] > 5) & (mdata['FEH_PASTEL'] < 5) & (mdata['LOGG_PASTEL'] < 10) & (mdata['LOGG_PASTEL'] > 0) & (mdata['FEH_PASTEL'] < 0.5)

# %%
mdata = mdata[mask]

# %% [markdown]
# Checking to see that the data was all masked properly.

# %%
for it,sep in enumerate(seps):    
    # Creating the histogram of the separation values
    histo = plt.hist(mdata[sep[0]],bins=100)
    plt.title('Angular Separation [\"] of Pristine and '+sep[1])
    # Determining the median
    plt.axvline(meds[it],c='k',label='Median')
    # Determining the Median Absolute Deviation
    plt.axvline(meds[it]+3*mads[it],c='k',linestyle='dashed',label=r'Median+3*MAD')
    plt.legend(fancybox=True)
    plt.show()

# %% [markdown]
# Now the data table "mdata" should have values that were cross-matched and are within 3 MAD of the median

# %% [markdown]
# lets save this table as its own thing then for easy importing in the future.

# %%
newhdu = fits.BinTableHDU(mdata)
newhdu.writeto('/arc/home/aydanmckay/phottable-x-lamost-post-edit.fits',overwrite=True)

# %%
mdata.columns
# Out:
# ColDefs(
#     name = 'ra'; format = 'D'
#     name = 'dec'; format = 'D'
#     name = 'CaHK'; format = 'D'
#     name = 'e_CaHK_1'; format = 'D'
#     name = 'flag_1'; format = 'K'; null = -9223372036854775808
#     name = 'E_BV_1'; format = 'D'
#     name = 'obsid'; format = 'D'
#     name = 'ra_obs'; format = 'D'
#     name = 'dec_obs'; format = 'D'
#     name = 'FEH_APOGEE'; format = 'D'
#     name = 'MH_APOGEE'; format = 'D'
#     name = 'CH_APOGEE'; format = 'D'
#     name = 'NH_APOGEE'; format = 'D'
#     name = 'CFE_APOGEE'; format = 'D'
#     name = 'NFE_APOGEE'; format = 'D'
#     name = 'AFE_APOGEE'; format = 'D'
#     name = 'LOGG_APOGEE'; format = 'D'
#     name = 'TEFF_PASTEL'; format = 'D'
#     name = 'LOGG_PASTEL'; format = 'D'
#     name = 'FEH_PASTEL'; format = 'D'
#     name = 'A_GG'; format = 'D'
#     name = 'A_BP'; format = 'D'
#     name = 'A_RP'; format = 'D'
#     name = 'A_J'; format = 'D'
#     name = 'A_H'; format = 'D'
#     name = 'A_KS'; format = 'D'
#     name = 'A_W1'; format = 'D'
#     name = 'A_W2'; format = 'D'
#     name = 'A_BAP'; format = 'D'
#     name = 'A_VAP'; format = 'D'
#     name = 'A_RAP'; format = 'D'
#     name = 'A_GSD'; format = 'D'
#     name = 'A_RSD'; format = 'D'
#     name = 'A_ISD'; format = 'D'
#     name = 'snrg'; format = 'E'
#     name = 'rv'; format = 'E'
#     name = 'err_rv'; format = 'E'
#     name = 'err_teff_pastel'; format = 'D'
#     name = 'err_feh_pastel'; format = 'D'
#     name = 'err_logg_pastel'; format = 'D'
#     name = 'err_feh_apogee'; format = 'D'
#     name = 'err_mh_apogee'; format = 'D'
#     name = 'err_afe_apogee'; format = 'D'
#     name = 'err_cfe_apogee'; format = 'D'
#     name = 'err_nfe_apogee'; format = 'D'
#     name = 'err_logg_apogee'; format = 'D'
#     name = 'err_a_gg'; format = 'D'
#     name = 'err_a_bp'; format = 'D'
#     name = 'err_a_rp'; format = 'D'
#     name = 'a_bprp'; format = 'D'
#     name = 'err_a_bprp'; format = 'D'
#     name = 'err_a_j'; format = 'D'
#     name = 'err_a_h'; format = 'D'
#     name = 'err_a_ks'; format = 'D'
#     name = 'err_a_bap'; format = 'D'
#     name = 'err_a_vap'; format = 'D'
#     name = 'err_a_rap'; format = 'D'
#     name = 'err_a_gsd'; format = 'D'
#     name = 'err_a_rsd'; format = 'D'
#     name = 'err_a_isd'; format = 'D'
#     name = 'err_a_w1'; format = 'D'
#     name = 'err_a_w2'; format = 'D'
#     name = 'mh_afe'; format = 'D'
#     name = 'err_mh_afe'; format = 'D'
#     name = 'GAIAID'; format = '19A'
#     name = 'EBV'; format = 'E'
#     name = 'uqflag'; format = 'D'
#     name = 'dist_phot'; format = 'D'
#     name = 'err_dist_phot'; format = 'D'
#     name = 'gl'; format = 'D'
#     name = 'gb'; format = 'D'
#     name = 'u'; format = 'D'
#     name = 'v'; format = 'D'
#     name = 'w'; format = 'D'
#     name = 'e_u'; format = 'D'
#     name = 'e_v'; format = 'D'
#     name = 'e_w'; format = 'D'
#     name = 'vr'; format = 'D'
#     name = 'vphi'; format = 'D'
#     name = 'vz'; format = 'D'
#     name = 'e_vr'; format = 'D'
#     name = 'e_vphi'; format = 'D'
#     name = 'e_vz'; format = 'D'
#     name = 'feh_vmp'; format = 'D'
#     name = 'err_feh_vmp'; format = 'D'
#     name = 'flag_feh_apogee'; format = 'D'
#     name = 'flag_mh_apogee'; format = 'D'
#     name = 'flag_logg_apogee'; format = 'D'
#     name = 'flag_afe_apogee'; format = 'D'
#     name = 'flag_cfe_apogee'; format = 'D'
#     name = 'flag_nfe_apogee'; format = 'D'
#     name = 'flag_teff_pastel'; format = 'D'
#     name = 'flag_feh_pastel'; format = 'D'
#     name = 'flag_logg_pastel'; format = 'D'
#     name = 'flag_a_gg'; format = 'D'
#     name = 'flag_a_bp'; format = 'D'
#     name = 'flag_a_rp'; format = 'D'
#     name = 'flag_a_j'; format = 'D'
#     name = 'flag_a_h'; format = 'D'
#     name = 'flag_a_ks'; format = 'D'
#     name = 'flag_a_w1'; format = 'D'
#     name = 'flag_a_w2'; format = 'D'
#     name = 'flag_a_bap'; format = 'D'
#     name = 'flag_a_vap'; format = 'D'
#     name = 'flag_a_rap'; format = 'D'
#     name = 'flag_a_gsd'; format = 'D'
#     name = 'flag_a_rsd'; format = 'D'
#     name = 'flag_a_isd'; format = 'D'
#     name = 'source_id'; format = 'K'; null = -9223372036854775808
#     name = 'parallax'; format = 'D'; unit = 'mas'
#     name = 'parallax_error'; format = 'D'; unit = 'mas'
#     name = 'parallax_over_error'; format = 'D'
#     name = 'pm'; format = 'D'; unit = 'mas yr-1'
#     name = 'pmra_1'; format = 'D'; unit = 'mas yr-1'
#     name = 'pmra_error'; format = 'D'; unit = 'mas yr-1'
#     name = 'pmdec'; format = 'D'; unit = 'mas yr-1'
#     name = 'pmdec_error'; format = 'D'; unit = 'mas yr-1'
#     name = 'phot_g_mean_mag'; format = 'D'; unit = 'mag'
#     name = 'phot_bp_mean_mag'; format = 'D'; unit = 'mag'
#     name = 'phot_rp_mean_mag'; format = 'D'; unit = 'mag'
#     name = 'dr2_radial_velocity'; format = 'D'; unit = 'km s-1'
#     name = 'dr2_radial_velocity_error'; format = 'D'; unit = 'km s-1'
#     name = 'dr2_rv_nb_transits'; format = 'I'; null = -32768
#     name = 'dr2_rv_template_teff'; format = 'E'; unit = 'K'
#     name = 'dr2_rv_template_logg'; format = 'E'; unit = '[cgs]'
#     name = 'phot_g_mean_mag_error'; format = 'D'; unit = 'mag'
#     name = 'phot_bp_mean_mag_error'; format = 'D'; unit = 'mag'
#     name = 'phot_rp_mean_mag_error'; format = 'D'; unit = 'mag'
#     name = 'angDist_1'; format = 'D'; unit = 'arcsec'
#     name = 'Separation_1'; format = 'D'; unit = 'arcsec'
#     name = 'e_CaHK_2'; format = 'D'
#     name = 'flag_2'; format = 'K'; null = -9223372036854775808
#     name = 'E_BV_2'; format = 'D'
#     name = 'RAJ2000'; format = 'D'; unit = 'deg'
#     name = 'DEJ2000'; format = 'D'; unit = 'deg'
#     name = 'Jmag'; format = 'E'; unit = 'mag'
#     name = 'Hmag'; format = 'E'; unit = 'mag'
#     name = 'Kmag'; format = 'E'; unit = 'mag'
#     name = 'e_Jmag'; format = 'E'; unit = 'mag'
#     name = 'e_Hmag'; format = 'E'; unit = 'mag'
#     name = 'e_Kmag'; format = 'E'; unit = 'mag'
#     name = 'Qfl'; format = '3A'
#     name = 'angDist_2'; format = 'D'; unit = 'arcsec'
#     name = 'Separation_1a'; format = 'D'
#     name = 'e_CaHK_1a'; format = 'D'
#     name = 'flag_1a'; format = 'K'; null = -9223372036854775808
#     name = 'u_cfht'; format = 'D'
#     name = 'r_cfht'; format = 'D'
#     name = 'u_cfht_err'; format = 'D'
#     name = 'r_cfht_err'; format = 'D'
#     name = 'Separation_2'; format = 'D'; unit = 'arcsec'
#     name = 'Separation_1b'; format = 'D'
#     name = 'e_CaHK_2a'; format = 'D'
#     name = 'flag_2a'; format = 'K'; null = -9223372036854775808
#     name = 'i_ps'; format = 'E'
#     name = 'i_ps_err'; format = 'E'
#     name = 'Separation_2a'; format = 'D'; unit = 'arcsec'
#     name = 'Separation_1c'; format = 'D'
#     name = 'e_CaHK_1b'; format = 'D'
#     name = 'flag_1b'; format = 'K'; null = -9223372036854775808
#     name = 'TYPE'; format = '3A'
#     name = 'FLUX_G'; format = 'E'; unit = 'nanomaggy'
#     name = 'FLUX_R'; format = 'E'; unit = 'nanomaggy'
#     name = 'FLUX_Z'; format = 'E'; unit = 'nanomaggy'
#     name = 'FLUX_W1'; format = 'E'; unit = 'nanomaggy'
#     name = 'FLUX_W2'; format = 'E'; unit = 'nanomaggy'
#     name = 'FLUX_W3'; format = 'E'; unit = 'nanomaggy'
#     name = 'FLUX_W4'; format = 'E'; unit = 'nanomaggy'
#     name = 'FLUX_IVAR_G'; format = 'E'; unit = '1/nanomaggy^2'
#     name = 'FLUX_IVAR_R'; format = 'E'; unit = '1/nanomaggy^2'
#     name = 'FLUX_IVAR_Z'; format = 'E'; unit = '1/nanomaggy^2'
#     name = 'FLUX_IVAR_W1'; format = 'E'; unit = '1/nanomaggy^2'
#     name = 'FLUX_IVAR_W2'; format = 'E'; unit = '1/nanomaggy^2'
#     name = 'FLUX_IVAR_W3'; format = 'E'; unit = '1/nanomaggy^2'
#     name = 'FLUX_IVAR_W4'; format = 'E'; unit = '1/nanomaggy^2'
#     name = 'Z_SPEC'; format = 'E'
#     name = 'Separation_2b'; format = 'D'; unit = 'arcsec'
#     name = 'Separation_1d'; format = 'D'
#     name = 'e_CaHK_2b'; format = 'D'
#     name = 'flag_2b'; format = 'K'; null = -9223372036854775808
#     name = 'E_BV'; format = 'D'
#     name = 'umag'; format = 'E'; unit = 'mag'
#     name = 'gmag_1'; format = 'E'; unit = 'mag'
#     name = 'rmag_1'; format = 'E'; unit = 'mag'
#     name = 'imag_1'; format = 'E'; unit = 'mag'
#     name = 'zmag_1'; format = 'E'; unit = 'mag'
#     name = 'e_umag'; format = 'E'; unit = 'mag'
#     name = 'e_gmag_1'; format = 'E'; unit = 'mag'
#     name = 'e_rmag_1'; format = 'E'; unit = 'mag'
#     name = 'e_imag_1'; format = 'E'; unit = 'mag'
#     name = 'e_zmag_1'; format = 'E'; unit = 'mag'
#     name = 'pmRA_2'; format = 'E'; unit = 'mas/yr'
#     name = 'pmDE'; format = 'E'; unit = 'mas/yr'
#     name = 'e_pmRA'; format = 'E'; unit = 'mas/yr'
#     name = 'e_pmDE'; format = 'E'; unit = 'mas/yr'
#     name = 'angDist_1a'; format = 'D'; unit = 'arcsec'
#     name = 'Separation_1e'; format = 'D'
#     name = 'Qual'; format = 'I'; null = -32768
#     name = 'gmag_2'; format = 'E'; unit = 'mag'
#     name = 'e_gmag_2'; format = 'E'; unit = 'mag'
#     name = 'gFlags'; format = 'J'; null = -2147483648
#     name = 'rmag_2'; format = 'E'; unit = 'mag'
#     name = 'e_rmag_2'; format = 'E'; unit = 'mag'
#     name = 'rFlags'; format = 'J'; null = -2147483648
#     name = 'imag_2'; format = 'E'; unit = 'mag'
#     name = 'e_imag_2'; format = 'E'; unit = 'mag'
#     name = 'iFlags'; format = 'J'; null = -2147483648
#     name = 'zmag_2'; format = 'E'; unit = 'mag'
#     name = 'e_zmag_2'; format = 'E'; unit = 'mag'
#     name = 'zFlags'; format = 'J'; null = -2147483648
#     name = 'ymag'; format = 'E'; unit = 'mag'
#     name = 'e_ymag'; format = 'E'; unit = 'mag'
#     name = 'yFlags'; format = 'J'; null = -2147483648
#     name = 'angDist_2a'; format = 'D'; unit = 'arcsec'
#     name = 'Separation'; format = 'D'
# )

# %%
plt.scatter(mdata['TEFF_PASTEL'],mdata['LOGG_PASTEL'],c=mdata['FEH_PASTEL'],s=.1) # rduce point size.
plt.hist2d(mdata['TEFF_PASTEL'],mdata['LOGG_PASTEL'],bins=250)
c = plt.colorbar()
plt.xlabel(r'$T_{eff}$')
plt.ylabel(r'log $g$');
c.set_label('N');
plt.xlim(7000,4000)
plt.ylim(5,2);
# plt.savefig('kieldiaghist.png')

# %%
plt.hist(mdata['FEH_PASTEL'],bins=100)
plt.xlim(0.135,-4)
plt.xlabel('[Fe/H]')
plt.ylabel('N')
# plt.savefig('metallicityhist.png')

# %%
hdul = fits.open('/arc/projects/k-pop/catalogues/lamost-dr8-gaiaedr3.fits')
lamost = hdul[1].data

# %%
plt.scatter(lamost['TEFF_PASTEL'],lamost['LOGG_PASTEL'],c=lamost['FEH_PASTEL'])
c = plt.colorbar()
plt.xlabel(r'$T_{eff}$')
plt.ylabel(r'log $g$');
c.set_label('[Fe/H]')
# plt.savefig('kieldiaglamostnocuts.png')

# %%
lamost.columns
# Out:
# ColDefs(
#     name = 'obsid'; format = 'D'
#     name = 'ra_obs'; format = 'D'
#     name = 'dec_obs'; format = 'D'
#     name = 'FEH_APOGEE'; format = 'D'
#     name = 'MH_APOGEE'; format = 'D'
#     name = 'CH_APOGEE'; format = 'D'
#     name = 'NH_APOGEE'; format = 'D'
#     name = 'CFE_APOGEE'; format = 'D'
#     name = 'NFE_APOGEE'; format = 'D'
#     name = 'AFE_APOGEE'; format = 'D'
#     name = 'LOGG_APOGEE'; format = 'D'
#     name = 'TEFF_PASTEL'; format = 'D'
#     name = 'LOGG_PASTEL'; format = 'D'
#     name = 'FEH_PASTEL'; format = 'D'
#     name = 'A_GG'; format = 'D'
#     name = 'A_BP'; format = 'D'
#     name = 'A_RP'; format = 'D'
#     name = 'A_J'; format = 'D'
#     name = 'A_H'; format = 'D'
#     name = 'A_KS'; format = 'D'
#     name = 'A_W1'; format = 'D'
#     name = 'A_W2'; format = 'D'
#     name = 'A_BAP'; format = 'D'
#     name = 'A_VAP'; format = 'D'
#     name = 'A_RAP'; format = 'D'
#     name = 'A_GSD'; format = 'D'
#     name = 'A_RSD'; format = 'D'
#     name = 'A_ISD'; format = 'D'
#     name = 'snrg'; format = 'E'
#     name = 'rv'; format = 'E'
#     name = 'err_rv'; format = 'E'
#     name = 'err_teff_pastel'; format = 'D'
#     name = 'err_feh_pastel'; format = 'D'
#     name = 'err_logg_pastel'; format = 'D'
#     name = 'err_feh_apogee'; format = 'D'
#     name = 'err_mh_apogee'; format = 'D'
#     name = 'err_afe_apogee'; format = 'D'
#     name = 'err_cfe_apogee'; format = 'D'
#     name = 'err_nfe_apogee'; format = 'D'
#     name = 'err_logg_apogee'; format = 'D'
#     name = 'err_a_gg'; format = 'D'
#     name = 'err_a_bp'; format = 'D'
#     name = 'err_a_rp'; format = 'D'
#     name = 'a_bprp'; format = 'D'
#     name = 'err_a_bprp'; format = 'D'
#     name = 'err_a_j'; format = 'D'
#     name = 'err_a_h'; format = 'D'
#     name = 'err_a_ks'; format = 'D'
#     name = 'err_a_bap'; format = 'D'
#     name = 'err_a_vap'; format = 'D'
#     name = 'err_a_rap'; format = 'D'
#     name = 'err_a_gsd'; format = 'D'
#     name = 'err_a_rsd'; format = 'D'
#     name = 'err_a_isd'; format = 'D'
#     name = 'err_a_w1'; format = 'D'
#     name = 'err_a_w2'; format = 'D'
#     name = 'mh_afe'; format = 'D'
#     name = 'err_mh_afe'; format = 'D'
#     name = 'GAIAID'; format = '19A'
#     name = 'EBV'; format = 'E'
#     name = 'uqflag'; format = 'D'
#     name = 'dist_phot'; format = 'D'
#     name = 'err_dist_phot'; format = 'D'
#     name = 'x'; format = 'D'
#     name = 'err_x'; format = 'D'
#     name = 'y'; format = 'D'
#     name = 'err_y'; format = 'D'
#     name = 'z'; format = 'D'
#     name = 'err_z'; format = 'D'
#     name = 'r'; format = 'D'
#     name = 'err_r'; format = 'D'
#     name = 'phi'; format = 'D'
#     name = 'err_phi'; format = 'D'
#     name = 'gl'; format = 'D'
#     name = 'gb'; format = 'D'
#     name = 'u'; format = 'D'
#     name = 'v'; format = 'D'
#     name = 'w'; format = 'D'
#     name = 'e_u'; format = 'D'
#     name = 'e_v'; format = 'D'
#     name = 'e_w'; format = 'D'
#     name = 'vr'; format = 'D'
#     name = 'vphi'; format = 'D'
#     name = 'vz'; format = 'D'
#     name = 'e_vr'; format = 'D'
#     name = 'e_vphi'; format = 'D'
#     name = 'e_vz'; format = 'D'
#     name = 'feh_vmp'; format = 'D'
#     name = 'err_feh_vmp'; format = 'D'
#     name = 'flag_feh_apogee'; format = 'D'
#     name = 'flag_mh_apogee'; format = 'D'
#     name = 'flag_logg_apogee'; format = 'D'
#     name = 'flag_afe_apogee'; format = 'D'
#     name = 'flag_cfe_apogee'; format = 'D'
#     name = 'flag_nfe_apogee'; format = 'D'
#     name = 'flag_teff_pastel'; format = 'D'
#     name = 'flag_feh_pastel'; format = 'D'
#     name = 'flag_logg_pastel'; format = 'D'
#     name = 'flag_a_gg'; format = 'D'
#     name = 'flag_a_bp'; format = 'D'
#     name = 'flag_a_rp'; format = 'D'
#     name = 'flag_a_j'; format = 'D'
#     name = 'flag_a_h'; format = 'D'
#     name = 'flag_a_ks'; format = 'D'
#     name = 'flag_a_w1'; format = 'D'
#     name = 'flag_a_w2'; format = 'D'
#     name = 'flag_a_bap'; format = 'D'
#     name = 'flag_a_vap'; format = 'D'
#     name = 'flag_a_rap'; format = 'D'
#     name = 'flag_a_gsd'; format = 'D'
#     name = 'flag_a_rsd'; format = 'D'
#     name = 'flag_a_isd'; format = 'D'
#     name = 'ra_epoch2000'; format = 'D'; unit = 'deg'
#     name = 'dec_epoch2000'; format = 'D'; unit = 'deg'
#     name = 'errHalfMaj'; format = 'E'; unit = 'arcsec'
#     name = 'errHalfMin'; format = 'E'; unit = 'arcsec'
#     name = 'errPosAng'; format = 'E'; unit = 'deg'
#     name = 'source_id'; format = 'K'
#     name = 'parallax'; format = 'D'; unit = 'mas'
#     name = 'parallax_error'; format = 'D'; unit = 'mas'
#     name = 'parallax_over_error'; format = 'D'
#     name = 'pm'; format = 'D'; unit = 'mas/yr'
#     name = 'pmra'; format = 'D'; unit = 'mas/yr'
#     name = 'pmra_error'; format = 'D'; unit = 'mas/yr'
#     name = 'pmdec'; format = 'D'; unit = 'mas/yr'
#     name = 'pmdec_error'; format = 'D'; unit = 'mas/yr'
#     name = 'astrometric_n_good_obs_al'; format = 'I'
#     name = 'astrometric_gof_al'; format = 'D'
#     name = 'astrometric_chi2_al'; format = 'D'
#     name = 'astrometric_excess_noise'; format = 'D'; unit = 'mas'
#     name = 'astrometric_excess_noise_sig'; format = 'D'
#     name = 'astrometric_params_solved'; format = 'B'
#     name = 'pseudocolour'; format = 'D'; unit = 'um-1'
#     name = 'pseudocolour_error'; format = 'D'; unit = 'um-1'
#     name = 'visibility_periods_used'; format = 'B'
#     name = 'ruwe'; format = 'D'
#     name = 'duplicated_source'; format = 'L'
#     name = 'phot_g_mean_flux'; format = 'D'; unit = 'e-/s'
#     name = 'phot_g_mean_flux_error'; format = 'D'; unit = 'e-/s'
#     name = 'phot_g_mean_mag'; format = 'D'; unit = 'mag'
#     name = 'phot_bp_mean_flux'; format = 'D'; unit = 'e-/s'
#     name = 'phot_bp_mean_flux_error'; format = 'D'; unit = 'e-/s'
#     name = 'phot_bp_mean_mag'; format = 'D'; unit = 'mag'
#     name = 'phot_rp_mean_flux'; format = 'D'; unit = 'e-/s'
#     name = 'phot_rp_mean_mag'; format = 'D'; unit = 'mag'
#     name = 'phot_bp_rp_excess_factor'; format = 'D'
#     name = 'bp_rp'; format = 'D'; unit = 'mag'
#     name = 'dr2_radial_velocity'; format = 'D'; unit = 'km/s'
#     name = 'dr2_radial_velocity_error'; format = 'D'; unit = 'km/s'
#     name = 'dr2_rv_nb_transits'; format = 'I'
#     name = 'dr2_rv_template_teff'; format = 'E'; unit = 'K'
#     name = 'dr2_rv_template_logg'; format = 'E'; unit = '[cgs]'
#     name = 'panstarrs1'; format = 'K'; null = -9223372036854775808
#     name = 'sdssdr13'; format = 'K'; null = -9223372036854775808
#     name = 'skymapper2'; format = 'J'; null = -2147483648
#     name = 'urat1'; format = 'J'; null = -2147483648
#     name = 'phot_g_mean_mag_error'; format = 'D'; unit = 'mag'
#     name = 'phot_bp_mean_mag_error'; format = 'D'; unit = 'mag'
#     name = 'phot_rp_mean_mag_error'; format = 'D'; unit = 'mag'
#     name = 'phot_g_mean_mag_corrected'; format = 'D'; unit = 'mag'
#     name = 'phot_g_mean_mag_error_corrected'; format = 'D'; unit = 'mag'
#     name = 'phot_g_mean_flux_corrected'; format = 'D'; unit = 'e-/s'
#     name = 'phot_bp_rp_excess_factor_corrected'; format = 'D'
#     name = 'ra_epoch2000_error'; format = 'D'; unit = 'mas'
#     name = 'dec_epoch2000_error'; format = 'D'; unit = 'mas'
#     name = 'ra_dec_epoch2000_corr'; format = 'D'
#     name = 'angDist'; format = 'D'; unit = 'arcsec'
# )

# %%
lamostmasked = lamost[(lamost['snrg'] > 20) & (lamost['visibility_periods_used'] > 8) & \
                      (lamost['astrometric_chi2_al']/(lamost['astrometric_n_good_obs_al']-5) < 1.44*np.exp(-0.4*(lamost['phot_g_mean_mag']-19.5))) & \
                      (lamost['astrometric_chi2_al']/(lamost['astrometric_n_good_obs_al']-5) < 1.44) & (lamost['TEFF_PASTEL'] > 4000) & (lamost['TEFF_PASTEL'] < 7500) & \
                      (lamost['parallax_over_error'] > 5) & (lamost['FEH_PASTEL'] < 5) & (lamost['LOGG_PASTEL'] < 5) & (lamost['LOGG_PASTEL'] > 0)]

# %% [markdown]
# LAMOST: We require that SNR > 20 in u, g, r, i or z band, and that qflag chi2 == ‘good’ and flag singlestar == ‘YES’.

# %%
plt.scatter(lamostmasked['TEFF_PASTEL'],lamostmasked['LOGG_PASTEL'],c=lamostmasked['FEH_PASTEL'])
c = plt.colorbar()
plt.xlabel(r'$T_{eff}$')
plt.ylabel(r'log $g$');
c.set_label('[Fe/H]')

# %%
np.unique(lamost['flag_feh_pastel'])
# Out:
# array([0., 1.])
