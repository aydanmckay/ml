# %% [markdown]
# Importing the required packages

# %%
#!/usr/bin/env python

from __future__ import print_function, division

import numpy as np
import scipy.stats
import h5py

import tensorflow as tf
from tensorflow import keras
import tensorflow.keras.backend as K
from tensorflow.python.ops import math_ops
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from glob import glob
from time import time
import json

# %%
def get_corr_matrix(cov):
    rho = cov.copy()
    sqrt_cov_diag = np.sqrt(cov[np.diag_indices(cov.shape[0])])
    rho /= sqrt_cov_diag[:,None]
    rho /= sqrt_cov_diag[None,:]
    rho[np.diag_indices(cov.shape[0])] = sqrt_cov_diag
    return rho

# %%
def get_inputs_outputs(d, pretrained_model=None,
                          recalc_reddening=False,
                          rchisq_max=None,
                          return_cov_components=False):
    n_bands = 110 # Gaia (G, BP, RP), PS1 (grizy), 2MASS (JHK), unWISE (W1,W2)
    n_atm_params = 3 # (T_eff, logg, [M/H])
    
    large_err = 999.

    # Stellar spectroscopic parameters
    print('Fill in stellar atmospheric parameters ...')
    x = np.empty((d.size,3), dtype='f4')
    x[:] = d['atm_param'][:]

    x_p = np.empty((d.size,3), dtype='f4')
    x_p = d['atm_param_p'][:]
    x_p = x_p[0]
    print(x_p.shape)

    # Magnitudes
    print('Fill in stellar magnitudes ...')
    y = np.empty((d.size,n_bands), dtype='f4')
    y[:] = d['bprp'][:]

    # Covariance of y
    print('Empty covariance matrix ...')
    cov_y = np.zeros((d.size,n_bands,n_bands), dtype='f4')

    # \delta m
    print('Covariance: \delta m ...')
    for i in range(n_bands):
        cov_y[:,i,i] = d['bprperr'][:,:,i]**2

    # Replace NaN magnitudes with median (in each band).
    # Also set corresponding variances to large number.
    print('Replace NaN magnitudes ...')
    for b in range(n_bands):
        idx = (
              ~np.isfinite(y[:,b])
            | ~np.isfinite(cov_y[:,b,b])
        )
        n_bad = np.count_nonzero(idx)
        n_tot = idx.size
        y0 = np.median(y[~idx,b])
        if np.isnan(y0):
            y0 = 0.
        print(f'Band {b}: {n_bad} of {n_tot} bad. Replacing with {y0:.5f}.')
        y[idx,b] = y0
        cov_y[idx,b,b] = large_err**2.

    # Transform both y and its covariance
    B = np.identity(n_bands, dtype='f4')
    B[1:,0] = -1.
    
    print('Transform y -> B y ...')
    y = np.einsum('ij,nj->ni', B, y) # y' = B y
    print('Transform C -> B C B^T ...')
    #cov_y = np.einsum('ik,nkl,jl->nij', B, cov_y, B) # C' = B C B^T
    cov_y = np.einsum('nik,jk->nij', cov_y, B)
    cov_y = np.einsum('ik,nkj->nij', B, cov_y)
    
    if return_cov_components:
        cov_comp = {
            'delta_m': cov_y.copy()
        }
    #########################################################################3
    # Add in dM/dtheta and dR/dtheta terms
    if pretrained_model is not None:
        print('Calculate J = dM/dtheta ...')
        J_M = calc_dmag_color_dtheta(pretrained_model, x_p)
        # cov_x = d['atm_param_cov_p']
        cov_x = d['atm_param_cov_p'][0]
        print('Covariance: J C_theta J^T ...')
        print('J_M.shape =',J_M.shape)
        print('cov_x.shape =',cov_x.shape)
        print('cov_y.shape =',cov_y.shape)
        cov_y += np.einsum('nik,nkl,njl->nij', J_M, cov_x, J_M)
        
        if return_cov_components:
            cov_comp['dM/dtheta'] = np.einsum('nik,nkl,njl->nij', J_M, cov_x, J_M)
    ##########################################################################
    # print('{:d} NaN parallaxes'.format(
    #     np.count_nonzero(np.isnan(d['parallax']))
    # ))
    # err_over_plx = d['parallax_err'] / d['parallax']
    # print('Covariance: DM uncertainty term ...')
    # cov_y[:,0,0] += (5./np.log(10.) * err_over_plx)**2.
    
    if return_cov_components:
        cov_comp['dm'] = np.zeros_like(cov_y)
        # cov_comp['dm'][:,0,0] = (5./np.log(10.) * err_over_plx)**2.

    # print('Estimate DM ...')
    # dm = 10. - 5.*np.log10(d['parallax'])# + 5./np.log(10.)*dm_corr
    # y[:,0] -= dm

    # # Don't attempt to predict M_G for poor plx/err or when plx < 0
    # print('Filter out M_G for poor parallax measurements ...')
    # idx = (
    #       (err_over_plx > 0.2)
    #     | (d['parallax'] < 1.e-8)
    #     | ~np.isfinite(d['parallax'])
    #     | ~np.isfinite(d['parallax_err'])
    # )
    # n_use = idx.size - np.count_nonzero(idx)
    # print(r'Using {:d} of {:d} ({:.3f}%) of stellar parallaxes.'.format(
    #     n_use, idx.size, n_use/idx.size*100.
    # ))
    # cov_y[idx,0,0] = large_err**2
    # y[idx,0] = np.nanmedian(y[:,0])
    
    if return_cov_components:
        cov_comp['dm'][idx,0,0] = large_err**2
###################################################################3
    if pretrained_model is not None:
        # Update reddenings, based on vector R and (y_obs - y_pred).
        # Use provided reddenings as a prior.

        # First, need to calculate inv_cov_y
        print('Invert C_y matrices ...')
        inv_cov_y = np.stack([np.linalg.inv(c) for c in cov_y])

        # Predict M & R for each star based on atm. params
        M_pred = predict_M(pretrained_model, x_p)
        
        # Calculate chi^2 for each star
        # chisq = calc_chisq(M_pred+r[:,None]*R-y, inv_cov_y)
        chisq = calc_chisq(M_pred-y, inv_cov_y)
        print('chisq =', chisq)

        # Calculate d.o.f. of each star
        print('Calculate d.o.f. of each star ...')
        n_dof = np.zeros(d.size, dtype='i4')
        for k in range(n_bands):
            n_dof += (cov_y[:,k,k] < (large_err-1.)**2).astype('i4')
        #print('n_dof =', n_dof)

        # Calculate reduced chi^2 for each star
        print('Calculate chi^2/d.o.f. for each star ...')
        rchisq = chisq / (n_dof - 1.00000001)
        pct = (0., 1., 10., 50., 90., 99., 100.)
        rchisq_pct = np.percentile(rchisq[np.isfinite(rchisq)], pct)
        print('chi^2/dof percentiles:')
        for p,rc in zip(pct,rchisq_pct):
            print(rf'  {p:.0f}% : {rc:.3g}')
        idx_rchisq = (rchisq < 10.)
        print(f'<chi^2/d.o.f.> = {np.mean(rchisq[idx_rchisq]):.3g}')
        
        # Filter on reduced chi^2
        if rchisq_max is not None:
            print('Filter on chi^2/d.o.f. ...')
            idx = np.isfinite(rchisq) & (rchisq > 0.) & (rchisq < rchisq_max)
            n_filt = np.count_nonzero(~idx)
            pct_filt = 100. * n_filt / idx.size
            print(
                rf'Filtering {n_filt:d} stars ({pct_filt:.3g}%) ' +
                rf'based on chi^2/dof > {rchisq_max:.1f}'
            )
            x = x[idx]
            x_p = x_p[idx]
            # r = r[idx]
            y = y[idx]
            cov_y = cov_y[idx]
            # r_var = r_var[idx]
            rchisq = rchisq[idx]
            
            if return_cov_components:
                for key in cov_comp:
                    cov_comp[key] = cov_comp[key][idx]
############################################################################3
#     # Cholesky transform of inverse covariance: L L^T = C^(-1).
#     print('Cholesky transform of each stellar covariance matrix ...')
#     LT = np.empty_like(cov_y)
    # inv_cov_y = np.empty_like(cov_y)
    # for k,c in enumerate(cov_y):
    #     try:
#             # Inflate diagonal of cov slightly, to ensure
#             # positive-definiteness
#             c_diag = c[np.diag_indices_from(c)]
#             c[np.diag_indices_from(c)] += 1.e-4 + 1.e-3 * c_diag
            
#             inv_cov_y[k] = np.linalg.inv(c)
#             LT[k] = np.linalg.cholesky(inv_cov_y[k]).T
#             #ic = np.linalg.inv(c)
#             #LT.append(np.linalg.cholesky(ic).T)
#             #inv_cov_y.append(ic)
#         except np.linalg.LinAlgError as e:
#             rho = get_corr_matrix(c)
#             print('Offending correlation matrix:')
#             print(np.array2string(
#                 rho[:6,:6],
#                 formatter={'float_kind':lambda z:'{: >7.4f}'.format(z)}
#             ))
#             print('Offending covariance matrix:')
#             print(np.array2string(
#                 c[:6,:6],
#                 formatter={'float_kind':lambda z:'{: >9.6f}'.format(z)}
#             ))
#             print('Covariance matrix of (normed) atmospheric parameters:')
#             print(d['atm_param_cov_p'][k])
#             # if pretrained_model is not None:
#             #     print(f'Variance of r: {r_var[k]:.8f}')
            
#             # Inflate errors along the diagonal and try again
#             c_diag = c[np.diag_indices_from(c)]
#             c[np.diag_indices_from(c)] += 0.02 + 0.02 * c_diag
#             rho = get_corr_matrix(c)
#             print('Inflated correlation matrix:')
#             print(np.array2string(
#                 rho[:6,:6],
#                 formatter={'float_kind':lambda z:'{: >7.4f}'.format(z)}
#             ))
            
#             inv_cov_y[k] = np.linalg.inv(c)
#             LT[k] = np.linalg.cholesky(inv_cov_y[k]).T
#             #raise e

#     #print('Stack L^T matrices ...')
#     #LT = np.stack(LT)
#     #print('Stack C^(-1) matrices ...')
#     #inv_cov_y = np.stack(inv_cov_y)

#     # L^T y
#     print('Calculate L^T y ...')
#     LTy = np.einsum('nij,nj->ni', LT, y)

    print('Gather inputs and outputs and return ...')
    # inputs_outputs = {
    #     'x':x, 'x_p':x_p, 'r':r, 'y':y,
    #     'LT':LT, 'LTy':LTy,
    #     'cov_y':cov_y, 'inv_cov_y':inv_cov_y,
    # }
    inputs_outputs = {
        'x':x, 'x_p':x_p, 'y':y,
        'cov_y':cov_y,# 'inv_cov_y':inv_cov_y,
    }
    
    if return_cov_components:
        inputs_outputs['cov_comp'] = cov_comp
    
    # if pretrained_model is not None:
        # inputs_outputs['r_var'] = r_var
        inputs_outputs['rchisq'] = rchisq

    # Check that there are no NaNs or Infs in results
    for key in inputs_outputs:
        if isinstance(inputs_outputs[key], dict):
            continue
        if key == 'rchisq': # Infs appear when d.o.f. = 1
            continue
        if np.any(~np.isfinite(inputs_outputs[key])):
            raise ValueError(f'NaNs or Infs detected in {key}.')

    return inputs_outputs

# %%
def predict_M(nn_model, x_p):
    """
    Predicts (absmag0,color1,color2,...) for input
    normalized stellar parameters.

    Inputs:
        nn_model (keras.Model): Neural network model.
        x_p (np.ndarray): Normalized stellar parameters.
            Shape = (n_stars, 3).
    
    Outputs:
        M (np.ndarray): Shape = (n_stars, n_bands).
    """
    inputs = nn_model.get_layer(name='theta').input
    outputs = nn_model.get_layer(name='B_BPRP').output
    mag_color_model = keras.Model(inputs, outputs)
    M = mag_color_model.predict(x_p)
    return M

# %%
def save_predictions(fname, nn_model, d_test, io_test):
    M_pred = predict_M(nn_model, io_test['x_p'])
    
    with h5py.File(fname, 'w') as f:
        f.create_dataset('/data', data=d_test, chunks=True,
                         compression='gzip', compression_opts=3)
        f.create_dataset('/y_obs', data=io_test['y'], chunks=True,
                         compression='gzip', compression_opts=3)
        f.create_dataset('/cov_y', data=io_test['cov_y'], chunks=True,
                         compression='gzip', compression_opts=3)
        # f.create_dataset('/r_fit', data=io_test['r'], chunks=True,
        #                  compression='gzip', compression_opts=3)
        f.create_dataset('/M_pred', data=M_pred, chunks=True,
                         compression='gzip', compression_opts=3)
        # f.create_dataset('/R_pred', data=R_pred, chunks=True,
        #                 compression='gzip', compression_opts=3)
        f.attrs['R0'] = R0
        
        if 'cov_comp' in io_test:
            for key in io_test['cov_comp']:
                f.create_dataset(
                    f'/cov_comp/{key.replace(r"/","_")}',
                    data=io_test['cov_comp'][key],
                    chunks=True,
                    compression='gzip',
                    compression_opts=3
                )

# %%
def calc_chisq(dy, inv_cov_y):
    """
    Returns the chi^2 for each observation, given
    an array of residuals and inverse covariance matrices.
    
        chi^2 = dy^T C^{-1} dy.
    
    Inputs:
        dy (np.ndarray): Residual values. Shape = (n_obs, n_dim),
            where n_obs is the number of observations, and n_dim is
            the dimensionality of the vector space.
        inv_cov_y (np.ndarray): Inverse covariance matrices.
            Shape = (n_obs, n_dim, n_dim).
    
    Returns:
        chisq (np.ndarray): Chi^2 for each observation. Shape=(n_obs,).
    """
    C_inv_dy = np.einsum('nij,nj->ni', inv_cov_y, dy)
    chisq = np.einsum('ni,ni->n', dy, C_inv_dy)
    return chisq

# %% [markdown]
# ##### Creates NN model

# %%
def get_nn_model():
    # Stellar model: B M(theta)
    atm = keras.Input(shape=(3,), name='theta')
    x = atm
    x = keras.layers.Dense(
        32,
        activation='gelu',
        kernel_regularizer=keras.regularizers.l2(l=1.e-4),
        name=f'stellar_bprp_model_hidden_0'
        )(x)
    x = keras.layers.Dense(
        64,
        activation='gelu',
        kernel_regularizer=keras.regularizers.l2(l=1.e-4),
        name=f'stellar_bprp_model_hidden_1'
        )(x)
    x = keras.layers.Dense(
        128,
        activation='gelu',
        kernel_regularizer=keras.regularizers.l2(l=1.e-4),
        name=f'stellar_bprp_model_hidden_2',
        )(x)
    spec_xp = keras.layers.Dense(110, name='B_BPRP')(x)

    # Compile model
    model = keras.Model(
        inputs=atm,
        outputs=spec_xp,
        name='stellar_BPRP_model'
    )
    model.compile(
        loss='mse',
        # loss='mae',
        optimizer='Adam',
        metrics=['mse']
        # metrics=['mae']
    )

    return model

def save_theta_norm(d_attrs, fname):
    d = {
        'theta_med': d_attrs['atm_param_med'].tolist(),
        'theta_std': d_attrs['atm_param_std'].tolist()
    }
    with open(fname, 'w') as f:
        json.dump(d, f)

# %%
def train_model(nn_model, io_train, k, n_iterations, epochs=100,
                checkpoint_fn='checkpoint', batch_size=32,
                suff='_'):
    checkpoint_fn = (
          'checkpoints/'
        + checkpoint_fn
        + '.e{epoch:03d}_vl{val_loss:.3f}.h5'
    )
    callbacks = [
        keras.callbacks.ModelCheckpoint(
            filepath=checkpoint_fn,
            save_best_only=True,
            monitor='val_loss',
            verbose=1
        )#, PlotLearning()
    ]
    inputs = io_train['x_p']
    outputs = io_train['y']
    # print(inputs.shape)
    # print(outputs.shape)
    nn_model.fit(
        inputs, outputs,
        epochs=epochs,
        validation_split=0.25/0.9,
        callbacks=callbacks,
        batch_size=batch_size,
        verbose=True
    )
    plt.title('Loss: Iteration {} of {}.'.format(k+1, n_iterations))
    plt.plot(range(1,epochs+1),nn_model.history.history['loss'],label='loss')
    plt.plot(range(1,epochs+1),nn_model.history.history['val_loss'],label='val_loss')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend()
    plt.grid()
    plt.savefig('/arc/home/aydanmckay/networkplots/train_val_loss'+suff+'.svg', dpi=150)
    plt.close()

# %%
def evaluate_model(nn_model, io_eval, batch_size=32, rchisq_max=None):
    """
    Runs the model on the given inputs and outputs, and returns the
    MSE and loss.
    
    Inputs:
        nn_model (keras.Model): The neural network model.
        io_eval (dict): A dictionary containing, among other things,
            x_p, r, LT and LTy. If rchisq_max is provided, then the
            dictionary must also contain rchisq.
        batch_size (int): Defaults to 32.
        rchisq_max (float): Stars with greater than this reduced chi^2
            will not be included in the calculation. Defaults to None.
    
    Returns:
        A list containing the MSE and loss.
    """
    inputs = io_eval['x_p']
    outputs = io_eval['y']
    
    if rchisq_max is not None:
        idx = (io_eval['rchisq'] < rchisq_max)
        inputs = inputs[idx]
        outputs = outputs[idx]
    
    loss = nn_model.evaluate(
        inputs,
        outputs,
        batch_size=batch_size,
        verbose=0
    )
    
    loss = [float(x) for x in loss] # Make JSON serializable
    return loss

# %%
def diagnostic_plots(nn_model, io_test, d_test, suffix=None):
    if suffix is None:
        suff = ''
    else:
        suff = '_' + suffix
    
    inputs = [
        nn_model.get_layer(name='theta').input,
        nn_model.get_layer(name='E').input
    ]
    outputs = nn_model.get_layer(name='B_M_plus_A').output
    absmag_model = keras.Model(inputs, outputs)

    # Predict y for the test dataset
    test_pred = {
        'y': absmag_model.predict([
            io_test['x_p']
        ]),
    }
    test_pred['y_resid'] = io_test['y'] - test_pred['y']

    # Read out colors, magnitudes
    g = io_test['y'][:,3] + io_test['y'][:,0]
    ri = io_test['y'][:,4] - io_test['y'][:,5]
    gr = io_test['y'][:,3] - io_test['y'][:,4]
    g_pred = test_pred['y'][:,3] + test_pred['y'][:,0]
    ri_pred = test_pred['y'][:,4] - test_pred['y'][:,5]
    gr_pred = test_pred['y'][:,3] - test_pred['y'][:,4]

    gaia_g = io_test['y'][:,0]
    bp_rp = io_test['y'][:,1] - io_test['y'][:,2]
    gaia_g_pred = test_pred['y'][:,0]
    bp_rp_pred = test_pred['y'][:,1] - test_pred['y'][:,2]

    print('g =', g)
    print('ri =', ri)
    print('gr =', gr)
    print('gaia_g =', gaia_g)
    print('bp_rp =', bp_rp)

    # Plot HRD
    params = {
        'density': (None, r'$N$', (None, None)),
        'teff': (d_test['atm_param'][:,0], r'$T_{\mathrm{eff}}$', (4000., 8000.)),
        'logg': (d_test['atm_param'][:,1], r'$\log \left( g \right)$', (0., 5.)),
        'mh': (d_test['atm_param'][:,2], r'$\left[ \mathrm{M} / \mathrm{H} \right]$', (-2.5, 0.5))
    }

    plot_spec = [
        {
            'colors': [(1,2), (4,5)],
            'mag': 0
        },
        {
            'colors': [(3,4), (4,5)],
            'mag': 0
        }
    ]

    idx_goodobs = np.isfinite(d_test['mag_err'])
    idx_goodobs &= (np.abs(io_test['cov_y'][:,0,0]) < 90.)[:,None]
    idx_goodobs = idx_goodobs.T

    def scatter_or_hexbin(ax, x, y, c, vmin, vmax, extent):
        if p == 'density':
            im = ax.hexbin(
                x, y,
                extent=extent,
                bins='log',
                rasterized=True
            )
        else:
            im = ax.scatter(
                x,
                y,
                c=c,
                edgecolors='none',
                alpha=0.1,
                vmin=vmin,
                vmax=vmax,
                rasterized=True
            )
        return im

    def get_lim(*args, **kwargs):
        expand = kwargs.get('expand', 0.4)
        expand_low = kwargs.get('expand_low', expand)
        expand_high = kwargs.get('expand_high', expand)
        pct = kwargs.get('pct', 1.)
        lim = [np.inf, -np.inf]
        for a in args:
            a0,a1 = np.nanpercentile(a, [pct, 100.-pct])
            lim[0] = min(a0, lim[0])
            lim[1] = max(a1, lim[1])
        w = lim[1] - lim[0]
        lim[0] -= expand_low * w
        lim[1] += expand_high * w
        return lim

    labels = ['G', 'BP', 'RP', 'g', 'r', 'i', 'z', 'y']

    for ps in plot_spec:
        mag_label = r'$M_{{ {} }}$'.format(labels[ps['mag']])
        mag_obs = io_test['y'][:,ps['mag']]
        mag_pred = test_pred['y'][:,ps['mag']]
        print('mag_pred:',mag_pred)

        if ps['mag'] != 0:
            mag_obs += io_test['y'][:,0]
            mag_pred += io_test['y'][:,0]

        color_labels = []
        colors_obs = []
        colors_pred = []
        idx_colors_obs = []
        E_vec = []
        for i1,i2 in ps['colors']:
            color_labels.append(r'${} - {}$'.format(labels[i1], labels[i2]))
            colors_obs.append(io_test['y'][:,i1] - io_test['y'][:,i2])
            colors_pred.append(test_pred['y'][:,i1] - test_pred['y'][:,i2])
            idx_colors_obs.append(idx_goodobs[i1] & idx_goodobs[i2])

        mag_lim = get_lim(
            mag_obs[idx_goodobs[ps['mag']]],
            pct=2.
        )[::-1]
        color_lim = [
            get_lim(c[idx_colors_obs[k]], expand_low=0.5, expand_high=0.4)
            for k,c in enumerate(colors_obs)
        ]
        
        for p in params.keys():
            c, label, (vmin,vmax) = params[p]
            
            fig = plt.figure(figsize=(14,4.5), dpi=150)
            fig.patch.set_alpha(0.)
            gs = GridSpec(
                1,4,
                width_ratios=[1,1,1,0.1],
                left=0.07, right=0.93,
                bottom=0.10, top=0.92
            )
            ax_obs = fig.add_subplot(gs[0,0], facecolor='gray')
            ax_pred = fig.add_subplot(gs[0,1], facecolor='gray')
            cax = fig.add_subplot(gs[0,3], facecolor='w')

            extent = color_lim[0] + mag_lim

            idx = (
                  idx_goodobs[ps['mag']]
                & idx_goodobs[ps['colors'][0][0]]
                & idx_goodobs[ps['colors'][0][1]]
            )
            im = scatter_or_hexbin(
                ax_obs,
                colors_obs[0][idx],
                mag_obs[idx],
                c if c is None else c[idx],
                vmin, vmax,
                extent
                #(-0.3,1.0,11.5,-2.0)
            )

            ax_obs.set_xlim(color_lim[0])
            ax_obs.set_ylim(mag_lim)
            ax_obs.set_xlabel(color_labels[0])
            ax_obs.set_ylabel(mag_label)
            ax_obs.grid('on', alpha=0.3)
            ax_obs.set_title(r'$\mathrm{Observed}$')

            im = scatter_or_hexbin(
                ax_pred,
                colors_pred[0],
                mag_pred,
                c,
                vmin, vmax,
                extent
            )

            ax_pred.set_xlim(color_lim[0])
            ax_pred.set_ylim(mag_lim)
            ax_pred.set_xlabel(color_labels[0])
            ax_pred.grid('on', alpha=0.3)
            ax_pred.set_title(r'$\mathrm{Predicted}$')

            cb = fig.colorbar(im, cax=cax)
            cb.set_label(label)
            cb.set_alpha(1.)
            cb.draw_all()

            cm_desc = '{}_vs_{}{}'.format(
                labels[ps['mag']],
                labels[ps['colors'][0][0]],
                labels[ps['colors'][0][1]]
            )
            fig.savefig(
                '/arc/home/aydanmckay/networkplots/nn_predictions_'+cm_desc+'_'+p+suff+'.svg',
                dpi=150,
                facecolor=fig.get_facecolor(),
                edgecolor='none'
            )
            plt.close(fig)

            # Color-color diagrams
            fig = plt.figure(figsize=(14,4.5), dpi=150)
            fig.patch.set_alpha(0.)
            gs = GridSpec(
                1,4,
                width_ratios=[1,1,1,0.1],
                left=0.07, right=0.93,
                bottom=0.10, top=0.92
            )
            ax_obs = fig.add_subplot(gs[0,0], facecolor='gray')
            ax_pred = fig.add_subplot(gs[0,1], facecolor='gray')
            cax = fig.add_subplot(gs[0,3], facecolor='w')

            extent = color_lim[0] + color_lim[1]

            idx = (
                  idx_goodobs[ps['colors'][0][0]]
                & idx_goodobs[ps['colors'][0][1]]
                & idx_goodobs[ps['colors'][1][0]]
                & idx_goodobs[ps['colors'][1][1]]
            )

            im = scatter_or_hexbin(
                ax_obs,
                colors_obs[0][idx],
                colors_obs[1][idx],
                c if c is None else c[idx],
                vmin, vmax,
                extent
                #(-0.2,1.5,-0.15,0.8)
            )
            ax_obs.set_xlim(color_lim[0])
            ax_obs.set_ylim(color_lim[1])
            ax_obs.set_xlabel(color_labels[0], fontsize=14)
            ax_obs.set_ylabel(color_labels[1], fontsize=14)
            ax_obs.grid('on', alpha=0.3)
            ax_obs.set_title(r'$\mathrm{Observed}$')

            im = scatter_or_hexbin(
                ax_pred,
                colors_pred[0][idx],
                colors_pred[1][idx],
                c if c is None else c[idx],
                #c,
                vmin, vmax,
                extent
            )
            ax_pred.set_xlim(color_lim[0])
            ax_pred.set_ylim(color_lim[1])
            ax_pred.set_xlabel(color_labels[0], fontsize=14)
            ax_pred.grid('on', alpha=0.3)
            ax_pred.set_title(r'$\mathrm{Predicted}$')

            cb = fig.colorbar(im, cax=cax)
            cb.set_label(label, fontsize=14)
            cb.set_alpha(1.)
            cb.draw_all()

            cc_desc = '{}{}_vs_{}{}'.format(
                labels[ps['colors'][0][0]],
                labels[ps['colors'][0][1]],
                labels[ps['colors'][1][0]],
                labels[ps['colors'][1][1]]
            )
            fig.savefig(
                '/arc/home/aydanmckay/networkplots/test_'+cc_desc+'_'+p+suff+'.svg',
                dpi=150,
                facecolor=fig.get_facecolor(),
                edgecolor='none'
            )
            plt.close(fig)
    
    # # Plot histograms of residuals
    # dr = (io_test['r'] - d_test['r'])/np.hypot(np.nanstd(d_test['r']),.01)
    # # dmag = (io_test['LTy'] - d_test['mag'])
    # # dm1,dm2,dm3,dm4,dm5,dm6,dm7,dm8,dm9,dm10,dm11,dm12,dm13 = dmag.T
    # names = ['G','(BP-G)','(RP-G)','(g-G)','(r-G)','(i-G)','(z-G)','(y-G)','(J-G)','(H-G)','(K_s-G)','(W_1-G)','(W_2-G)']
    # # ds = [dm1,dm2,dm3,dm4,dm5,dm6,dm7,dm8,dm9,dm10,dm11,dm12,dm13]
    # fig = plt.figure(figsize=(12,18))
    # ax = fig.add_subplot(5,3,1)
    # dr_mean = np.nanmean(dr)
    # dr_std = np.nanstd(dr)
    # ax.hist(dr, bins=50)
    # dr_skew = scipy.stats.moment(dr, moment=3, nan_policy='omit')
    # dr_txt = r'$\Delta E = {:+.3f} \pm {:.3f}$'.format(dr_mean, dr_std)
    # dr_skew /= (dr_std**1.5 + 1.e-5)
    # dr_txt += '\n' + r'$\tilde{{\mu}}_3 = {:+.3f}$'.format(dr_skew)
    # ax.text(0.05, 0.95, dr_txt, ha='left', va='top', transform=ax.transAxes)
    # ax.set_xlabel(r'$\Delta E \ \left( \mathrm{estimated} - \mathrm{Bayestar19} \right)$',fontsize=10)
    # for it,(io,dm,name) in enumerate(zip(io_test['LTy'].T,d_test['mag'].T,names)):
    #     dd = (io - dm)/np.hypot(np.nanstd(dm),.01)
    #     ax = fig.add_subplot(5,3,it+2)
    #     dd_mean = np.nanmean(dd)
    #     dd_std = np.nanstd(dd)
    #     ax.hist(dd, bins=50)
    #     dd_skew = scipy.stats.moment(dd, moment=3, nan_policy='omit')
    #     dd_txt = r'$\Delta '+name+r' = {:+.3f} \pm {:.3f}$'.format(dd_mean, dd_std)
    #     dd_skew /= (dd_std**1.5 + 1.e-5)
    #     dd_txt += '\n' + r'$\tilde{{\mu}}_3 = {:+.3f}$'.format(dd_skew)
    #     ax.text(0.05, 0.95, dd_txt, ha='left', va='top', transform=ax.transAxes)
    #     ax.set_xlabel(r'$\Delta '+name+r'\ \left( \mathrm{estimated} - \mathrm{observed} \right)$',fontsize=10)
    # fig.savefig('/arc/home/aydanmckay/networkplots/test_z-score_dE'+suff+'.svg', dpi=150)
    # plt.close(fig)

# %%
def calc_dmag_color_dtheta(nn_model, x_p):
    m = keras.Model(
        inputs=nn_model.get_layer(name='theta').input,
        outputs=nn_model.get_layer(name='B_BPRP').output
    )
    with tf.GradientTape() as g:
        x_p = tf.constant(x_p)
        g.watch(x_p)
        mag_color = m(x_p)
    J = g.batch_jacobian(mag_color, x_p).numpy()
    return J

# %% [markdown]
# ##### start of main()

# %%
# Load/create neural network
nn_name = 'xp_l2_mse_lr02'
nn_model = get_nn_model()
nn_model.summary()
# Out:
# 2022-07-05 16:36:17.597121: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "stellar_BPRP_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  theta (InputLayer)          [(None, 3)]               0
#
#  stellar_bprp_model_hidden_0  (None, 32)               128
#   (Dense)
#
#  stellar_bprp_model_hidden_1  (None, 64)               2112
#   (Dense)
#
#  stellar_bprp_model_hidden_2  (None, 128)              8320
#   (Dense)
#
#  B_BPRP (Dense)              (None, 110)               14190
#
# =================================================================
# Total params: 24,750
# Trainable params: 24,750
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Load stellar data
print('Loading data ...')
fname = '/arc/home/aydanmckay/ml/network/datasets/dr3datasmall.h5'

print(f'Loading {fname} ...')
attrs = {}
with h5py.File(fname, 'r') as f:
    dset = f['io_data']
    for key in dset.attrs.keys():
        attrs[key] = dset.attrs[key]
    d = dset[:]
save_theta_norm(attrs, 'thetanorms/xp_theta_normalization.json')
# Out:
# Loading data ...
# Loading /arc/home/aydanmckay/ml/network/datasets/dr3datasmall.h5 ...

# %%
# (training+validation) / test split
# Fix random seed (same split every run)
np.random.seed(42)
split = train_test_split(d, test_size=.1)
d_train = np.array(split[::2])
d_test = np.array(split[1::2])
np.random.shuffle(d_train)
print(f'{d_train.size: >10d} training/validation stars.')
print(f'{d_test.size: >10d} test stars.')
# Out:
#      90000 training/validation stars.
#      10000 test stars.

# %%
# Iteratively update dM/dtheta contribution to uncertainties,
# reddening estimates and reduced chi^2 cut, and retrain.
n_iterations = 20

# On GPU, use large batch sizes for memory transfer efficiency
# batch_size = 1024
batch_size = 256

rchisq_max_init = 100.
rchisq_max_final = 5.
rchisq_max = np.exp(np.linspace(
    np.log(rchisq_max_init),
    np.log(rchisq_max_final),
    n_iterations-6
))
rchisq_max = [None] + rchisq_max.tolist() + 5*[rchisq_max_final]
print('chi^2/dof = {}'.format(rchisq_max))
# Out:
# chi^2/dof = [None, 100.00000000000004, 79.41833348134496, 63.07271692954115, 50.09130066684769, 39.78167620874025, 31.593944275926187, 25.091384024965357, 19.927159040031896, 15.825817619770502, 12.56860061341878, 9.981773149103292, 7.927357886906197, 6.295775522882865, 4.999999999999999, 5.0, 5.0, 5.0, 5.0, 5.0]

# %%
for k in range(0, n_iterations):
    
    '''Transform data to inputs and outputs
    On subsequent iterations, inflate errors using
    gradients dM/dtheta from trained model, and derive new
    estimates of the reddenings of the stars.'''
    t0 = time()
    io_train = get_inputs_outputs(
        d_train,
        pretrained_model=None if k == 0 else nn_model,
        recalc_reddening=True,
        rchisq_max=rchisq_max[k]
    )                                
    io_test = get_inputs_outputs(
        d_test,
        pretrained_model=None if k == 0 else nn_model,
        recalc_reddening=True,
    )                                                                        
    t1 = time()
    print(f'Time elapsed to prepare data: {t1-t0:.2f} s')
    # Set learning rate based on the iteration
    lr = 0.01 * np.exp(-0.2*k)
    # lr = 0.01*np.exp(-0.02*k)
    print('learning rate = {}'.format(K.get_value(nn_model.optimizer.lr)))
    print('setting learning rate to {}'.format(lr))
    K.set_value(nn_model.optimizer.lr, lr)

    n_hidden = 4
    # Train the model
    print('Iteration {} of {}.'.format(k+1, n_iterations))
    t0 = time()
    train_model(
        nn_model,
        io_train,
        k,
        n_iterations,
        epochs=25,
        checkpoint_fn='{:s}_{:d}hidden_it{:d}'.format(
            nn_name, n_hidden, k
        ),
        batch_size=batch_size,
        suff='{:s}_{:d}hidden_it{:d}'.format(nn_name, n_hidden, k)
    )
    t1 = time()
    print(f'Time elapsed to train: {t1-t0:.2f} s')
    nn_model.save(
        'models/{:s}_{:d}hidden_it{:d}.h5'.format(
            nn_name, n_hidden, k
        )
    )
    nn_model = keras.models.load_model(
       'models/{:s}_{:d}hidden_it{:d}.h5'.format(nn_name, n_hidden, k)
    )

    # # Plot results on test set
    # print('Diagnostic plots ...')
    # t0 = time()
    # diagnostic_plots(
    #    nn_model,
    #    io_test,
    #    d_test,
    #    #io_train,
    #    #d_train,
    #    suffix='{:s}_{:d}hidden_it{:d}'.format(nn_name, n_hidden, k)
    # )
    # t1 = time()
    # print(f'Time elapsed to make plots: {t1-t0:.2f} s')
# Out:
# Fill in stellar atmospheric parameters ...
# (90000, 3)
# Fill in stellar magnitudes ...
# Empty covariance matrix ...
# Covariance: \delta m ...
# Replace NaN magnitudes ...
# Band 0: 0 of 90000 bad. Replacing with 2612.85376.
# Band 1: 0 of 90000 bad. Replacing with -188.65933.
# Band 2: 0 of 90000 bad. Replacing with -18.31512.
# Band 3: 0 of 90000 bad. Replacing with 6.18737.
# Band 4: 0 of 90000 bad. Replacing with -10.64803.
# Band 5: 0 of 90000 bad. Replacing with -2.49388.
# Band 6: 0 of 90000 bad. Replacing with -4.17958.
# Band 7: 0 of 90000 bad. Replacing with 1.43300.
# Band 8: 0 of 90000 bad. Replacing with -2.10850.
# Band 9: 0 of 90000 bad. Replacing with 0.57402.
# Band 10: 0 of 90000 bad. Replacing with 0.63645.
# Band 11: 0 of 90000 bad. Replacing with 0.40025.
# Band 12: 0 of 90000 bad. Replacing with -0.54446.
# Band 13: 0 of 90000 bad. Replacing with -0.95632.
# Band 14: 0 of 90000 bad. Replacing with 0.17720.
# Band 15: 0 of 90000 bad. Replacing with -0.45189.
# Band 16: 0 of 90000 bad. Replacing with 0.29390.
# Band 17: 0 of 90000 bad. Replacing with 0.11636.
# Band 18: 0 of 90000 bad. Replacing with -0.12801.
# Band 19: 0 of 90000 bad. Replacing with -0.46552.
# Band 20: 0 of 90000 bad. Replacing with -0.26635.
# Band 21: 0 of 90000 bad. Replacing with 0.50923.
# Band 22: 0 of 90000 bad. Replacing with 0.07312.
# Band 23: 0 of 90000 bad. Replacing with 0.03610.
# Band 24: 0 of 90000 bad. Replacing with -0.29431.
# Band 25: 0 of 90000 bad. Replacing with 0.06263.
# Band 26: 0 of 90000 bad. Replacing with 0.01547.
# Band 27: 0 of 90000 bad. Replacing with -0.09176.
# Band 28: 0 of 90000 bad. Replacing with 0.09417.
# Band 29: 0 of 90000 bad. Replacing with -0.14315.
# Band 30: 0 of 90000 bad. Replacing with -0.07631.
# Band 31: 0 of 90000 bad. Replacing with -0.03953.
# Band 32: 0 of 90000 bad. Replacing with -0.01734.
# Band 33: 0 of 90000 bad. Replacing with -0.04669.
# Band 34: 0 of 90000 bad. Replacing with 0.02825.
# Band 35: 0 of 90000 bad. Replacing with -0.01485.
# Band 36: 0 of 90000 bad. Replacing with -0.02775.
# Band 37: 0 of 90000 bad. Replacing with -0.09105.
# Band 38: 0 of 90000 bad. Replacing with 0.21907.
# Band 39: 0 of 90000 bad. Replacing with -0.00444.
# Band 40: 0 of 90000 bad. Replacing with -0.01220.
# Band 41: 0 of 90000 bad. Replacing with -0.06824.
# Band 42: 0 of 90000 bad. Replacing with 0.06865.
# Band 43: 0 of 90000 bad. Replacing with 0.12618.
# Band 44: 0 of 90000 bad. Replacing with -0.01853.
# Band 45: 0 of 90000 bad. Replacing with 0.06758.
# Band 46: 0 of 90000 bad. Replacing with -0.00802.
# Band 47: 0 of 90000 bad. Replacing with -0.01267.
# Band 48: 0 of 90000 bad. Replacing with -0.03340.
# Band 49: 0 of 90000 bad. Replacing with -0.00787.
# Band 50: 0 of 90000 bad. Replacing with 0.05393.
# Band 51: 0 of 90000 bad. Replacing with -0.01438.
# Band 52: 0 of 90000 bad. Replacing with -0.00225.
# Band 53: 0 of 90000 bad. Replacing with -0.00966.
# Band 54: 0 of 90000 bad. Replacing with -0.02330.
# Band 55: 0 of 90000 bad. Replacing with 3036.96289.
# Band 56: 0 of 90000 bad. Replacing with -283.52008.
# Band 57: 0 of 90000 bad. Replacing with -6.74791.
# Band 58: 0 of 90000 bad. Replacing with -0.17156.
# Band 59: 0 of 90000 bad. Replacing with 1.57187.
# Band 60: 0 of 90000 bad. Replacing with -2.52910.
# Band 61: 0 of 90000 bad. Replacing with -1.71546.
# Band 62: 0 of 90000 bad. Replacing with 0.35792.
# Band 63: 0 of 90000 bad. Replacing with -1.25865.
# Band 64: 0 of 90000 bad. Replacing with 0.33275.
# Band 65: 0 of 90000 bad. Replacing with 0.50876.
# Band 66: 0 of 90000 bad. Replacing with 0.17254.
# Band 67: 0 of 90000 bad. Replacing with -0.07569.
# Band 68: 0 of 90000 bad. Replacing with 0.29266.
# Band 69: 0 of 90000 bad. Replacing with -0.30981.
# Band 70: 0 of 90000 bad. Replacing with -0.29009.
# Band 71: 0 of 90000 bad. Replacing with -0.18011.
# Band 72: 0 of 90000 bad. Replacing with 0.22558.
# Band 73: 0 of 90000 bad. Replacing with 0.08554.
# Band 74: 0 of 90000 bad. Replacing with -0.10205.
# Band 75: 0 of 90000 bad. Replacing with 0.42031.
# Band 76: 0 of 90000 bad. Replacing with 0.09891.
# Band 77: 0 of 90000 bad. Replacing with -0.06152.
# Band 78: 0 of 90000 bad. Replacing with 0.10487.
# Band 79: 0 of 90000 bad. Replacing with 0.18044.
# Band 80: 0 of 90000 bad. Replacing with -0.04488.
# Band 81: 0 of 90000 bad. Replacing with -0.27265.
# Band 82: 0 of 90000 bad. Replacing with -0.27430.
# Band 83: 0 of 90000 bad. Replacing with -0.08382.
# Band 84: 0 of 90000 bad. Replacing with 0.11899.
# Band 85: 0 of 90000 bad. Replacing with -0.10379.
# Band 86: 0 of 90000 bad. Replacing with 0.25047.
# Band 87: 0 of 90000 bad. Replacing with 0.03519.
# Band 88: 0 of 90000 bad. Replacing with 0.01375.
# Band 89: 0 of 90000 bad. Replacing with 0.17253.
# Band 90: 0 of 90000 bad. Replacing with 0.08401.
# Band 91: 0 of 90000 bad. Replacing with -0.07828.
# Band 92: 0 of 90000 bad. Replacing with -0.00187.
# Band 93: 0 of 90000 bad. Replacing with 0.03493.
# Band 94: 0 of 90000 bad. Replacing with 0.00578.
# Band 95: 0 of 90000 bad. Replacing with 0.01046.
# Band 96: 0 of 90000 bad. Replacing with -0.14532.
# Band 97: 0 of 90000 bad. Replacing with -0.00097.
# Band 98: 0 of 90000 bad. Replacing with 0.04221.
# Band 99: 0 of 90000 bad. Replacing with -0.02619.
# Band 100: 0 of 90000 bad. Replacing with 0.03100.
# Band 101: 0 of 90000 bad. Replacing with 0.00363.
# Band 102: 0 of 90000 bad. Replacing with 0.02850.
# Band 103: 0 of 90000 bad. Replacing with -0.03859.
# Band 104: 0 of 90000 bad. Replacing with 0.01443.
# Band 105: 0 of 90000 bad. Replacing with 0.01329.
# Band 106: 0 of 90000 bad. Replacing with -0.01029.
# Band 107: 0 of 90000 bad. Replacing with 0.00666.
# Band 108: 0 of 90000 bad. Replacing with 0.00887.
# Band 109: 0 of 90000 bad. Replacing with 0.01525.
# Transform y -> B y ...
# Transform C -> B C B^T ...
# Gather inputs and outputs and return ...
# Fill in stellar atmospheric parameters ...
# (10000, 3)
# Fill in stellar magnitudes ...
# Empty covariance matrix ...
# Covariance: \delta m ...
# Replace NaN magnitudes ...
# Band 0: 0 of 10000 bad. Replacing with 2519.86768.
# Band 1: 0 of 10000 bad. Replacing with -185.48868.
# Band 2: 0 of 10000 bad. Replacing with -17.67404.
# Band 3: 0 of 10000 bad. Replacing with 6.11499.
# Band 4: 0 of 10000 bad. Replacing with -10.40044.
# Band 5: 0 of 10000 bad. Replacing with -2.52704.
# Band 6: 0 of 10000 bad. Replacing with -4.19596.
# Band 7: 0 of 10000 bad. Replacing with 1.46490.
# Band 8: 0 of 10000 bad. Replacing with -2.19853.
# Band 9: 0 of 10000 bad. Replacing with 0.56087.
# Band 10: 0 of 10000 bad. Replacing with 0.62344.
# Band 11: 0 of 10000 bad. Replacing with 0.35939.
# Band 12: 0 of 10000 bad. Replacing with -0.53096.
# Band 13: 0 of 10000 bad. Replacing with -0.92730.
# Band 14: 0 of 10000 bad. Replacing with 0.14079.
# Band 15: 0 of 10000 bad. Replacing with -0.45577.
# Band 16: 0 of 10000 bad. Replacing with 0.28794.
# Band 17: 0 of 10000 bad. Replacing with 0.12051.
# Band 18: 0 of 10000 bad. Replacing with -0.13238.
# Band 19: 0 of 10000 bad. Replacing with -0.44958.
# Band 20: 0 of 10000 bad. Replacing with -0.26492.
# Band 21: 0 of 10000 bad. Replacing with 0.49535.
# Band 22: 0 of 10000 bad. Replacing with 0.08438.
# Band 23: 0 of 10000 bad. Replacing with 0.03175.
# Band 24: 0 of 10000 bad. Replacing with -0.29904.
# Band 25: 0 of 10000 bad. Replacing with 0.05646.
# Band 26: 0 of 10000 bad. Replacing with 0.00629.
# Band 27: 0 of 10000 bad. Replacing with -0.08972.
# Band 28: 0 of 10000 bad. Replacing with 0.08224.
# Band 29: 0 of 10000 bad. Replacing with -0.13855.
# Band 30: 0 of 10000 bad. Replacing with -0.07389.
# Band 31: 0 of 10000 bad. Replacing with -0.02651.
# Band 32: 0 of 10000 bad. Replacing with -0.03307.
# Band 33: 0 of 10000 bad. Replacing with -0.03489.
# Band 34: 0 of 10000 bad. Replacing with 0.03333.
# Band 35: 0 of 10000 bad. Replacing with -0.02749.
# Band 36: 0 of 10000 bad. Replacing with -0.01370.
# Band 37: 0 of 10000 bad. Replacing with -0.08412.
# Band 38: 0 of 10000 bad. Replacing with 0.21914.
# Band 39: 0 of 10000 bad. Replacing with -0.00405.
# Band 40: 0 of 10000 bad. Replacing with -0.00845.
# Band 41: 0 of 10000 bad. Replacing with -0.06751.
# Band 42: 0 of 10000 bad. Replacing with 0.06643.
# Band 43: 0 of 10000 bad. Replacing with 0.12424.
# Band 44: 0 of 10000 bad. Replacing with -0.01247.
# Band 45: 0 of 10000 bad. Replacing with 0.07829.
# Band 46: 0 of 10000 bad. Replacing with -0.01485.
# Band 47: 0 of 10000 bad. Replacing with -0.01484.
# Band 48: 0 of 10000 bad. Replacing with -0.02285.
# Band 49: 0 of 10000 bad. Replacing with -0.00365.
# Band 50: 0 of 10000 bad. Replacing with 0.05589.
# Band 51: 0 of 10000 bad. Replacing with -0.01692.
# Band 52: 0 of 10000 bad. Replacing with -0.00244.
# Band 53: 0 of 10000 bad. Replacing with -0.00817.
# Band 54: 0 of 10000 bad. Replacing with -0.02454.
# Band 55: 0 of 10000 bad. Replacing with 2929.80273.
# Band 56: 0 of 10000 bad. Replacing with -271.45276.
# Band 57: 0 of 10000 bad. Replacing with -6.83614.
# Band 58: 0 of 10000 bad. Replacing with -0.25828.
# Band 59: 0 of 10000 bad. Replacing with 1.57831.
# Band 60: 0 of 10000 bad. Replacing with -2.45279.
# Band 61: 0 of 10000 bad. Replacing with -1.61302.
# Band 62: 0 of 10000 bad. Replacing with 0.35328.
# Band 63: 0 of 10000 bad. Replacing with -1.22888.
# Band 64: 0 of 10000 bad. Replacing with 0.36328.
# Band 65: 0 of 10000 bad. Replacing with 0.51836.
# Band 66: 0 of 10000 bad. Replacing with 0.17048.
# Band 67: 0 of 10000 bad. Replacing with -0.10558.
# Band 68: 0 of 10000 bad. Replacing with 0.30792.
# Band 69: 0 of 10000 bad. Replacing with -0.30396.
# Band 70: 0 of 10000 bad. Replacing with -0.28569.
# Band 71: 0 of 10000 bad. Replacing with -0.17943.
# Band 72: 0 of 10000 bad. Replacing with 0.23553.
# Band 73: 0 of 10000 bad. Replacing with 0.09229.
# Band 74: 0 of 10000 bad. Replacing with -0.10631.
# Band 75: 0 of 10000 bad. Replacing with 0.43443.
# Band 76: 0 of 10000 bad. Replacing with 0.09967.
# Band 77: 0 of 10000 bad. Replacing with -0.07085.
# Band 78: 0 of 10000 bad. Replacing with 0.08789.
# Band 79: 0 of 10000 bad. Replacing with 0.16128.
# Band 80: 0 of 10000 bad. Replacing with -0.04057.
# Band 81: 0 of 10000 bad. Replacing with -0.28594.
# Band 82: 0 of 10000 bad. Replacing with -0.27260.
# Band 83: 0 of 10000 bad. Replacing with -0.08840.
# Band 84: 0 of 10000 bad. Replacing with 0.12088.
# Band 85: 0 of 10000 bad. Replacing with -0.08976.
# Band 86: 0 of 10000 bad. Replacing with 0.23824.
# Band 87: 0 of 10000 bad. Replacing with 0.03630.
# Band 88: 0 of 10000 bad. Replacing with 0.02519.
# Band 89: 0 of 10000 bad. Replacing with 0.17770.
# Band 90: 0 of 10000 bad. Replacing with 0.09419.
# Band 91: 0 of 10000 bad. Replacing with -0.07830.
# Band 92: 0 of 10000 bad. Replacing with -0.00332.
# Band 93: 0 of 10000 bad. Replacing with 0.03753.
# Band 94: 0 of 10000 bad. Replacing with 0.00923.
# Band 95: 0 of 10000 bad. Replacing with 0.01108.
# Band 96: 0 of 10000 bad. Replacing with -0.14352.
# Band 97: 0 of 10000 bad. Replacing with -0.00540.
# Band 98: 0 of 10000 bad. Replacing with 0.04046.
# Band 99: 0 of 10000 bad. Replacing with -0.02886.
# Band 100: 0 of 10000 bad. Replacing with 0.03466.
# Band 101: 0 of 10000 bad. Replacing with 0.01331.
# Band 102: 0 of 10000 bad. Replacing with 0.02945.
# Band 103: 0 of 10000 bad. Replacing with -0.04120.
# Band 104: 0 of 10000 bad. Replacing with 0.01455.
# Band 105: 0 of 10000 bad. Replacing with 0.01535.
# Band 106: 0 of 10000 bad. Replacing with -0.01361.
# Band 107: 0 of 10000 bad. Replacing with 0.01189.
# Band 108: 0 of 10000 bad. Replacing with 0.00966.
# Band 109: 0 of 10000 bad. Replacing with 0.01380.
# Transform y -> B y ...
# Transform C -> B C B^T ...
# Gather inputs and outputs and return ...
# Time elapsed to prepare data: 194.62 s
# learning rate = 0.0010000000474974513
# setting learning rate to 0.01
# Iteration 1 of 20.
# Epoch 1/25
# 252/254 [============================>.] - ETA: 0s - loss: 553355200.0000 - mse: 553355200.0000
# Epoch 1: val_loss improved from inf to 496281120.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it0.e001_vl496281120.000.h5
# 254/254 [==============================] - 3s 9ms/step - loss: 554705472.0000 - mse: 554705472.0000 - val_loss: 496281120.0000 - val_mse: 496281120.0000
# Epoch 2/25
# 253/254 [============================>.] - ETA: 0s - loss: 517543296.0000 - mse: 517543296.0000
# Epoch 2: val_loss improved from 496281120.00000 to 494272928.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it0.e002_vl494272928.000.h5
# 254/254 [==============================] - 2s 8ms/step - loss: 536559808.0000 - mse: 536559808.0000 - val_loss: 494272928.0000 - val_mse: 494272928.0000
# Epoch 3/25
# 247/254 [============================>.] - ETA: 0s - loss: 539215040.0000 - mse: 539215040.0000
# Epoch 3: val_loss improved from 494272928.00000 to 492487488.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it0.e003_vl492487488.000.h5
# 254/254 [==============================] - 2s 8ms/step - loss: 536234976.0000 - mse: 536234976.0000 - val_loss: 492487488.0000 - val_mse: 492487488.0000
# Epoch 4/25
# 251/254 [============================>.] - ETA: 0s - loss: 538973120.0000 - mse: 538973120.0000
# Epoch 4: val_loss did not improve from 492487488.00000
# 254/254 [==============================] - 2s 7ms/step - loss: 534847104.0000 - mse: 534847104.0000 - val_loss: 494105152.0000 - val_mse: 494105152.0000
# Epoch 5/25
# 248/254 [============================>.] - ETA: 0s - loss: 529892480.0000 - mse: 529892480.0000
# Epoch 5: val_loss improved from 492487488.00000 to 490650368.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it0.e005_vl490650368.000.h5
# 254/254 [==============================] - 2s 8ms/step - loss: 534291680.0000 - mse: 534291680.0000 - val_loss: 490650368.0000 - val_mse: 490650368.0000
# Epoch 6/25
# 248/254 [============================>.] - ETA: 0s - loss: 538613248.0000 - mse: 538613248.0000
# Epoch 6: val_loss improved from 490650368.00000 to 489627040.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it0.e006_vl489627040.000.h5
# 254/254 [==============================] - 2s 8ms/step - loss: 533733792.0000 - mse: 533733792.0000 - val_loss: 489627040.0000 - val_mse: 489627040.0000
# Epoch 7/25
# 249/254 [============================>.] - ETA: 0s - loss: 536660192.0000 - mse: 536660192.0000
# Epoch 7: val_loss did not improve from 489627040.00000
# 254/254 [==============================] - 2s 7ms/step - loss: 532817120.0000 - mse: 532817120.0000 - val_loss: 491287776.0000 - val_mse: 491287776.0000
# Epoch 8/25
# 251/254 [============================>.] - ETA: 0s - loss: 531815008.0000 - mse: 531815008.0000
# Epoch 8: val_loss did not improve from 489627040.00000
# 254/254 [==============================] - 2s 8ms/step - loss: 532322016.0000 - mse: 532322016.0000 - val_loss: 489697632.0000 - val_mse: 489697632.0000
# Epoch 9/25
# 249/254 [============================>.] - ETA: 0s - loss: 533942016.0000 - mse: 533942016.0000
# Epoch 9: val_loss improved from 489627040.00000 to 487073824.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it0.e009_vl487073824.000.h5
# 254/254 [==============================] - 2s 8ms/step - loss: 530946560.0000 - mse: 530946560.0000 - val_loss: 487073824.0000 - val_mse: 487073824.0000
# Epoch 10/25
# 252/254 [============================>.] - ETA: 0s - loss: 529710048.0000 - mse: 529710048.0000
# Epoch 10: val_loss did not improve from 487073824.00000
# 254/254 [==============================] - 2s 7ms/step - loss: 530601152.0000 - mse: 530601152.0000 - val_loss: 488032384.0000 - val_mse: 488032384.0000
# Epoch 11/25
# 247/254 [============================>.] - ETA: 0s - loss: 534658784.0000 - mse: 534658784.0000
# Epoch 11: val_loss did not improve from 487073824.00000
# 254/254 [==============================] - 2s 8ms/step - loss: 530663392.0000 - mse: 530663392.0000 - val_loss: 488387488.0000 - val_mse: 488387488.0000
# Epoch 12/25
# 247/254 [============================>.] - ETA: 0s - loss: 530135328.0000 - mse: 530135328.0000
# Epoch 12: val_loss improved from 487073824.00000 to 486273088.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it0.e012_vl486273088.000.h5
# 254/254 [==============================] - 2s 7ms/step - loss: 530824160.0000 - mse: 530824160.0000 - val_loss: 486273088.0000 - val_mse: 486273088.0000
# Epoch 13/25
# 247/254 [============================>.] - ETA: 0s - loss: 531749152.0000 - mse: 531749152.0000
# Epoch 13: val_loss did not improve from 486273088.00000
# 254/254 [==============================] - 2s 8ms/step - loss: 530290240.0000 - mse: 530290240.0000 - val_loss: 487155392.0000 - val_mse: 487155392.0000
# Epoch 14/25
# 247/254 [============================>.] - ETA: 0s - loss: 531589248.0000 - mse: 531589248.0000
# Epoch 14: val_loss improved from 486273088.00000 to 485597184.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it0.e014_vl485597184.000.h5
# 254/254 [==============================] - 2s 8ms/step - loss: 530323616.0000 - mse: 530323616.0000 - val_loss: 485597184.0000 - val_mse: 485597184.0000
# Epoch 15/25
# 250/254 [============================>.] - ETA: 0s - loss: 523290080.0000 - mse: 523290080.0000
# Epoch 15: val_loss did not improve from 485597184.00000
# 254/254 [==============================] - 2s 7ms/step - loss: 529847648.0000 - mse: 529847648.0000 - val_loss: 488222304.0000 - val_mse: 488222304.0000
# Epoch 16/25
# 247/254 [============================>.] - ETA: 0s - loss: 535118304.0000 - mse: 535118304.0000
# Epoch 16: val_loss did not improve from 485597184.00000
# 254/254 [==============================] - 2s 8ms/step - loss: 529363680.0000 - mse: 529363680.0000 - val_loss: 486915616.0000 - val_mse: 486915616.0000
# Epoch 17/25
# 254/254 [==============================] - ETA: 0s - loss: 529512320.0000 - mse: 529512320.0000
# Epoch 17: val_loss did not improve from 485597184.00000
# 254/254 [==============================] - 2s 8ms/step - loss: 529512320.0000 - mse: 529512320.0000 - val_loss: 485783968.0000 - val_mse: 485783968.0000
# Epoch 18/25
# 249/254 [============================>.] - ETA: 0s - loss: 532660288.0000 - mse: 532660288.0000
# Epoch 18: val_loss did not improve from 485597184.00000
# 254/254 [==============================] - 2s 8ms/step - loss: 529563744.0000 - mse: 529563744.0000 - val_loss: 487532768.0000 - val_mse: 487532768.0000
# Epoch 19/25
# 254/254 [==============================] - ETA: 0s - loss: 529750528.0000 - mse: 529750528.0000
# Epoch 19: val_loss did not improve from 485597184.00000
# 254/254 [==============================] - 2s 8ms/step - loss: 529750528.0000 - mse: 529750528.0000 - val_loss: 487618176.0000 - val_mse: 487618176.0000
# Epoch 20/25
# 249/254 [============================>.] - ETA: 0s - loss: 528103232.0000 - mse: 528103232.0000
# Epoch 20: val_loss improved from 485597184.00000 to 484675264.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it0.e020_vl484675264.000.h5
# 254/254 [==============================] - 2s 8ms/step - loss: 529889184.0000 - mse: 529889184.0000 - val_loss: 484675264.0000 - val_mse: 484675264.0000
# Epoch 21/25
# 247/254 [============================>.] - ETA: 0s - loss: 536013472.0000 - mse: 536013472.0000
# Epoch 21: val_loss did not improve from 484675264.00000
# 254/254 [==============================] - 2s 8ms/step - loss: 529812128.0000 - mse: 529812128.0000 - val_loss: 484797376.0000 - val_mse: 484797376.0000
# Epoch 22/25
# 248/254 [============================>.] - ETA: 0s - loss: 510867680.0000 - mse: 510867680.0000
# Epoch 22: val_loss did not improve from 484675264.00000
# 254/254 [==============================] - 2s 8ms/step - loss: 529111008.0000 - mse: 529111008.0000 - val_loss: 487608736.0000 - val_mse: 487608736.0000
# Epoch 23/25
# 250/254 [============================>.] - ETA: 0s - loss: 533397696.0000 - mse: 533397696.0000
# Epoch 23: val_loss did not improve from 484675264.00000
# 254/254 [==============================] - 2s 7ms/step - loss: 529508224.0000 - mse: 529508224.0000 - val_loss: 486050592.0000 - val_mse: 486050592.0000
# Epoch 24/25
# 252/254 [============================>.] - ETA: 0s - loss: 529620640.0000 - mse: 529620640.0000
# Epoch 24: val_loss did not improve from 484675264.00000
# 254/254 [==============================] - 2s 7ms/step - loss: 529221824.0000 - mse: 529221824.0000 - val_loss: 484892416.0000 - val_mse: 484892416.0000
# Epoch 25/25
# 253/254 [============================>.] - ETA: 0s - loss: 530096672.0000 - mse: 530096672.0000
# Epoch 25: val_loss did not improve from 484675264.00000
# 254/254 [==============================] - 2s 8ms/step - loss: 528782784.0000 - mse: 528782784.0000 - val_loss: 485300736.0000 - val_mse: 485300736.0000
# Time elapsed to train: 49.94 s
# Fill in stellar atmospheric parameters ...
# (90000, 3)
# Fill in stellar magnitudes ...
# Empty covariance matrix ...
# Covariance: \delta m ...
# Replace NaN magnitudes ...
# Band 0: 0 of 90000 bad. Replacing with 2612.85376.
# Band 1: 0 of 90000 bad. Replacing with -188.65933.
# Band 2: 0 of 90000 bad. Replacing with -18.31512.
# Band 3: 0 of 90000 bad. Replacing with 6.18737.
# Band 4: 0 of 90000 bad. Replacing with -10.64803.
# Band 5: 0 of 90000 bad. Replacing with -2.49388.
# Band 6: 0 of 90000 bad. Replacing with -4.17958.
# Band 7: 0 of 90000 bad. Replacing with 1.43300.
# Band 8: 0 of 90000 bad. Replacing with -2.10850.
# Band 9: 0 of 90000 bad. Replacing with 0.57402.
# Band 10: 0 of 90000 bad. Replacing with 0.63645.
# Band 11: 0 of 90000 bad. Replacing with 0.40025.
# Band 12: 0 of 90000 bad. Replacing with -0.54446.
# Band 13: 0 of 90000 bad. Replacing with -0.95632.
# Band 14: 0 of 90000 bad. Replacing with 0.17720.
# Band 15: 0 of 90000 bad. Replacing with -0.45189.
# Band 16: 0 of 90000 bad. Replacing with 0.29390.
# Band 17: 0 of 90000 bad. Replacing with 0.11636.
# Band 18: 0 of 90000 bad. Replacing with -0.12801.
# Band 19: 0 of 90000 bad. Replacing with -0.46552.
# Band 20: 0 of 90000 bad. Replacing with -0.26635.
# Band 21: 0 of 90000 bad. Replacing with 0.50923.
# Band 22: 0 of 90000 bad. Replacing with 0.07312.
# Band 23: 0 of 90000 bad. Replacing with 0.03610.
# Band 24: 0 of 90000 bad. Replacing with -0.29431.
# Band 25: 0 of 90000 bad. Replacing with 0.06263.
# Band 26: 0 of 90000 bad. Replacing with 0.01547.
# Band 27: 0 of 90000 bad. Replacing with -0.09176.
# Band 28: 0 of 90000 bad. Replacing with 0.09417.
# Band 29: 0 of 90000 bad. Replacing with -0.14315.
# Band 30: 0 of 90000 bad. Replacing with -0.07631.
# Band 31: 0 of 90000 bad. Replacing with -0.03953.
# Band 32: 0 of 90000 bad. Replacing with -0.01734.
# Band 33: 0 of 90000 bad. Replacing with -0.04669.
# Band 34: 0 of 90000 bad. Replacing with 0.02825.
# Band 35: 0 of 90000 bad. Replacing with -0.01485.
# Band 36: 0 of 90000 bad. Replacing with -0.02775.
# Band 37: 0 of 90000 bad. Replacing with -0.09105.
# Band 38: 0 of 90000 bad. Replacing with 0.21907.
# Band 39: 0 of 90000 bad. Replacing with -0.00444.
# Band 40: 0 of 90000 bad. Replacing with -0.01220.
# Band 41: 0 of 90000 bad. Replacing with -0.06824.
# Band 42: 0 of 90000 bad. Replacing with 0.06865.
# Band 43: 0 of 90000 bad. Replacing with 0.12618.
# Band 44: 0 of 90000 bad. Replacing with -0.01853.
# Band 45: 0 of 90000 bad. Replacing with 0.06758.
# Band 46: 0 of 90000 bad. Replacing with -0.00802.
# Band 47: 0 of 90000 bad. Replacing with -0.01267.
# Band 48: 0 of 90000 bad. Replacing with -0.03340.
# Band 49: 0 of 90000 bad. Replacing with -0.00787.
# Band 50: 0 of 90000 bad. Replacing with 0.05393.
# Band 51: 0 of 90000 bad. Replacing with -0.01438.
# Band 52: 0 of 90000 bad. Replacing with -0.00225.
# Band 53: 0 of 90000 bad. Replacing with -0.00966.
# Band 54: 0 of 90000 bad. Replacing with -0.02330.
# Band 55: 0 of 90000 bad. Replacing with 3036.96289.
# Band 56: 0 of 90000 bad. Replacing with -283.52008.
# Band 57: 0 of 90000 bad. Replacing with -6.74791.
# Band 58: 0 of 90000 bad. Replacing with -0.17156.
# Band 59: 0 of 90000 bad. Replacing with 1.57187.
# Band 60: 0 of 90000 bad. Replacing with -2.52910.
# Band 61: 0 of 90000 bad. Replacing with -1.71546.
# Band 62: 0 of 90000 bad. Replacing with 0.35792.
# Band 63: 0 of 90000 bad. Replacing with -1.25865.
# Band 64: 0 of 90000 bad. Replacing with 0.33275.
# Band 65: 0 of 90000 bad. Replacing with 0.50876.
# Band 66: 0 of 90000 bad. Replacing with 0.17254.
# Band 67: 0 of 90000 bad. Replacing with -0.07569.
# Band 68: 0 of 90000 bad. Replacing with 0.29266.
# Band 69: 0 of 90000 bad. Replacing with -0.30981.
# Band 70: 0 of 90000 bad. Replacing with -0.29009.
# Band 71: 0 of 90000 bad. Replacing with -0.18011.
# Band 72: 0 of 90000 bad. Replacing with 0.22558.
# Band 73: 0 of 90000 bad. Replacing with 0.08554.
# Band 74: 0 of 90000 bad. Replacing with -0.10205.
# Band 75: 0 of 90000 bad. Replacing with 0.42031.
# Band 76: 0 of 90000 bad. Replacing with 0.09891.
# Band 77: 0 of 90000 bad. Replacing with -0.06152.
# Band 78: 0 of 90000 bad. Replacing with 0.10487.
# Band 79: 0 of 90000 bad. Replacing with 0.18044.
# Band 80: 0 of 90000 bad. Replacing with -0.04488.
# Band 81: 0 of 90000 bad. Replacing with -0.27265.
# Band 82: 0 of 90000 bad. Replacing with -0.27430.
# Band 83: 0 of 90000 bad. Replacing with -0.08382.
# Band 84: 0 of 90000 bad. Replacing with 0.11899.
# Band 85: 0 of 90000 bad. Replacing with -0.10379.
# Band 86: 0 of 90000 bad. Replacing with 0.25047.
# Band 87: 0 of 90000 bad. Replacing with 0.03519.
# Band 88: 0 of 90000 bad. Replacing with 0.01375.
# Band 89: 0 of 90000 bad. Replacing with 0.17253.
# Band 90: 0 of 90000 bad. Replacing with 0.08401.
# Band 91: 0 of 90000 bad. Replacing with -0.07828.
# Band 92: 0 of 90000 bad. Replacing with -0.00187.
# Band 93: 0 of 90000 bad. Replacing with 0.03493.
# Band 94: 0 of 90000 bad. Replacing with 0.00578.
# Band 95: 0 of 90000 bad. Replacing with 0.01046.
# Band 96: 0 of 90000 bad. Replacing with -0.14532.
# Band 97: 0 of 90000 bad. Replacing with -0.00097.
# Band 98: 0 of 90000 bad. Replacing with 0.04221.
# Band 99: 0 of 90000 bad. Replacing with -0.02619.
# Band 100: 0 of 90000 bad. Replacing with 0.03100.
# Band 101: 0 of 90000 bad. Replacing with 0.00363.
# Band 102: 0 of 90000 bad. Replacing with 0.02850.
# Band 103: 0 of 90000 bad. Replacing with -0.03859.
# Band 104: 0 of 90000 bad. Replacing with 0.01443.
# Band 105: 0 of 90000 bad. Replacing with 0.01329.
# Band 106: 0 of 90000 bad. Replacing with -0.01029.
# Band 107: 0 of 90000 bad. Replacing with 0.00666.
# Band 108: 0 of 90000 bad. Replacing with 0.00887.
# Band 109: 0 of 90000 bad. Replacing with 0.01525.
# Transform y -> B y ...
# Transform C -> B C B^T ...
# Calculate J = dM/dtheta ...
# Covariance: J C_theta J^T ...
# J_M.shape = (90000, 110, 3)
# cov_x.shape = (90000, 3, 3)
# cov_y.shape = (90000, 110, 110)
# Invert C_y matrices ...
# chisq = [ 7592.    9925.   50584.   ...  6859.25 21977.75 74392.5 ]
# Calculate d.o.f. of each star ...
# Calculate chi^2/d.o.f. for each star ...
# chi^2/dof percentiles:
#   0% : -7.69e+15
#   1% : -1.39e+13
#   10% : -3.97e+11
#   50% : 56.8
#   90% : 923
#   99% : 7.22e+11
#   100% : 4.49e+16
# <chi^2/d.o.f.> = -3.34e+12
# Filter on chi^2/d.o.f. ...
# Filtering 55715 stars (61.9%) based on chi^2/dof > 100.0
# Gather inputs and outputs and return ...
# Fill in stellar atmospheric parameters ...
# (10000, 3)
# Fill in stellar magnitudes ...
# Empty covariance matrix ...
# Covariance: \delta m ...
# Replace NaN magnitudes ...
# Band 0: 0 of 10000 bad. Replacing with 2519.86768.
# Band 1: 0 of 10000 bad. Replacing with -185.48868.
# Band 2: 0 of 10000 bad. Replacing with -17.67404.
# Band 3: 0 of 10000 bad. Replacing with 6.11499.
# Band 4: 0 of 10000 bad. Replacing with -10.40044.
# Band 5: 0 of 10000 bad. Replacing with -2.52704.
# Band 6: 0 of 10000 bad. Replacing with -4.19596.
# Band 7: 0 of 10000 bad. Replacing with 1.46490.
# Band 8: 0 of 10000 bad. Replacing with -2.19853.
# Band 9: 0 of 10000 bad. Replacing with 0.56087.
# Band 10: 0 of 10000 bad. Replacing with 0.62344.
# Band 11: 0 of 10000 bad. Replacing with 0.35939.
# Band 12: 0 of 10000 bad. Replacing with -0.53096.
# Band 13: 0 of 10000 bad. Replacing with -0.92730.
# Band 14: 0 of 10000 bad. Replacing with 0.14079.
# Band 15: 0 of 10000 bad. Replacing with -0.45577.
# Band 16: 0 of 10000 bad. Replacing with 0.28794.
# Band 17: 0 of 10000 bad. Replacing with 0.12051.
# Band 18: 0 of 10000 bad. Replacing with -0.13238.
# Band 19: 0 of 10000 bad. Replacing with -0.44958.
# Band 20: 0 of 10000 bad. Replacing with -0.26492.
# Band 21: 0 of 10000 bad. Replacing with 0.49535.
# Band 22: 0 of 10000 bad. Replacing with 0.08438.
# Band 23: 0 of 10000 bad. Replacing with 0.03175.
# Band 24: 0 of 10000 bad. Replacing with -0.29904.
# Band 25: 0 of 10000 bad. Replacing with 0.05646.
# Band 26: 0 of 10000 bad. Replacing with 0.00629.
# Band 27: 0 of 10000 bad. Replacing with -0.08972.
# Band 28: 0 of 10000 bad. Replacing with 0.08224.
# Band 29: 0 of 10000 bad. Replacing with -0.13855.
# Band 30: 0 of 10000 bad. Replacing with -0.07389.
# Band 31: 0 of 10000 bad. Replacing with -0.02651.
# Band 32: 0 of 10000 bad. Replacing with -0.03307.
# Band 33: 0 of 10000 bad. Replacing with -0.03489.
# Band 34: 0 of 10000 bad. Replacing with 0.03333.
# Band 35: 0 of 10000 bad. Replacing with -0.02749.
# Band 36: 0 of 10000 bad. Replacing with -0.01370.
# Band 37: 0 of 10000 bad. Replacing with -0.08412.
# Band 38: 0 of 10000 bad. Replacing with 0.21914.
# Band 39: 0 of 10000 bad. Replacing with -0.00405.
# Band 40: 0 of 10000 bad. Replacing with -0.00845.
# Band 41: 0 of 10000 bad. Replacing with -0.06751.
# Band 42: 0 of 10000 bad. Replacing with 0.06643.
# Band 43: 0 of 10000 bad. Replacing with 0.12424.
# Band 44: 0 of 10000 bad. Replacing with -0.01247.
# Band 45: 0 of 10000 bad. Replacing with 0.07829.
# Band 46: 0 of 10000 bad. Replacing with -0.01485.
# Band 47: 0 of 10000 bad. Replacing with -0.01484.
# Band 48: 0 of 10000 bad. Replacing with -0.02285.
# Band 49: 0 of 10000 bad. Replacing with -0.00365.
# Band 50: 0 of 10000 bad. Replacing with 0.05589.
# Band 51: 0 of 10000 bad. Replacing with -0.01692.
# Band 52: 0 of 10000 bad. Replacing with -0.00244.
# Band 53: 0 of 10000 bad. Replacing with -0.00817.
# Band 54: 0 of 10000 bad. Replacing with -0.02454.
# Band 55: 0 of 10000 bad. Replacing with 2929.80273.
# Band 56: 0 of 10000 bad. Replacing with -271.45276.
# Band 57: 0 of 10000 bad. Replacing with -6.83614.
# Band 58: 0 of 10000 bad. Replacing with -0.25828.
# Band 59: 0 of 10000 bad. Replacing with 1.57831.
# Band 60: 0 of 10000 bad. Replacing with -2.45279.
# Band 61: 0 of 10000 bad. Replacing with -1.61302.
# Band 62: 0 of 10000 bad. Replacing with 0.35328.
# Band 63: 0 of 10000 bad. Replacing with -1.22888.
# Band 64: 0 of 10000 bad. Replacing with 0.36328.
# Band 65: 0 of 10000 bad. Replacing with 0.51836.
# Band 66: 0 of 10000 bad. Replacing with 0.17048.
# Band 67: 0 of 10000 bad. Replacing with -0.10558.
# Band 68: 0 of 10000 bad. Replacing with 0.30792.
# Band 69: 0 of 10000 bad. Replacing with -0.30396.
# Band 70: 0 of 10000 bad. Replacing with -0.28569.
# Band 71: 0 of 10000 bad. Replacing with -0.17943.
# Band 72: 0 of 10000 bad. Replacing with 0.23553.
# Band 73: 0 of 10000 bad. Replacing with 0.09229.
# Band 74: 0 of 10000 bad. Replacing with -0.10631.
# Band 75: 0 of 10000 bad. Replacing with 0.43443.
# Band 76: 0 of 10000 bad. Replacing with 0.09967.
# Band 77: 0 of 10000 bad. Replacing with -0.07085.
# Band 78: 0 of 10000 bad. Replacing with 0.08789.
# Band 79: 0 of 10000 bad. Replacing with 0.16128.
# Band 80: 0 of 10000 bad. Replacing with -0.04057.
# Band 81: 0 of 10000 bad. Replacing with -0.28594.
# Band 82: 0 of 10000 bad. Replacing with -0.27260.
# Band 83: 0 of 10000 bad. Replacing with -0.08840.
# Band 84: 0 of 10000 bad. Replacing with 0.12088.
# Band 85: 0 of 10000 bad. Replacing with -0.08976.
# Band 86: 0 of 10000 bad. Replacing with 0.23824.
# Band 87: 0 of 10000 bad. Replacing with 0.03630.
# Band 88: 0 of 10000 bad. Replacing with 0.02519.
# Band 89: 0 of 10000 bad. Replacing with 0.17770.
# Band 90: 0 of 10000 bad. Replacing with 0.09419.
# Band 91: 0 of 10000 bad. Replacing with -0.07830.
# Band 92: 0 of 10000 bad. Replacing with -0.00332.
# Band 93: 0 of 10000 bad. Replacing with 0.03753.
# Band 94: 0 of 10000 bad. Replacing with 0.00923.
# Band 95: 0 of 10000 bad. Replacing with 0.01108.
# Band 96: 0 of 10000 bad. Replacing with -0.14352.
# Band 97: 0 of 10000 bad. Replacing with -0.00540.
# Band 98: 0 of 10000 bad. Replacing with 0.04046.
# Band 99: 0 of 10000 bad. Replacing with -0.02886.
# Band 100: 0 of 10000 bad. Replacing with 0.03466.
# Band 101: 0 of 10000 bad. Replacing with 0.01331.
# Band 102: 0 of 10000 bad. Replacing with 0.02945.
# Band 103: 0 of 10000 bad. Replacing with -0.04120.
# Band 104: 0 of 10000 bad. Replacing with 0.01455.
# Band 105: 0 of 10000 bad. Replacing with 0.01535.
# Band 106: 0 of 10000 bad. Replacing with -0.01361.
# Band 107: 0 of 10000 bad. Replacing with 0.01189.
# Band 108: 0 of 10000 bad. Replacing with 0.00966.
# Band 109: 0 of 10000 bad. Replacing with 0.01380.
# Transform y -> B y ...
# Transform C -> B C B^T ...
# Calculate J = dM/dtheta ...
# Covariance: J C_theta J^T ...
# J_M.shape = (10000, 110, 3)
# cov_x.shape = (10000, 3, 3)
# cov_y.shape = (10000, 110, 110)
# Invert C_y matrices ...
# chisq = [ 2527.1875 12348.25    9252.516  ... 62760.     38676.25   11748.25  ]
# Calculate d.o.f. of each star ...
# Calculate chi^2/d.o.f. for each star ...
# chi^2/dof percentiles:
#   0% : -3.29e+14
#   1% : -1.25e+13
#   10% : -3.66e+11
#   50% : 56.2
#   90% : 932
#   99% : 5.53e+11
#   100% : 1.89e+15
# <chi^2/d.o.f.> = -2.47e+12
# Gather inputs and outputs and return ...
# Time elapsed to prepare data: 446.45 s
# learning rate = 0.009999999776482582
# setting learning rate to 0.008187307530779819
# Iteration 2 of 20.
# Epoch 1/25
# 96/97 [============================>.] - ETA: 0s - loss: 11196929.0000 - mse: 11196929.0000
# Epoch 1: val_loss improved from inf to 10232549.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it1.e001_vl10232549.000.h5
# 97/97 [==============================] - 1s 9ms/step - loss: 11159641.0000 - mse: 11159641.0000 - val_loss: 10232549.0000 - val_mse: 10232545.0000
# Epoch 2/25
# 96/97 [============================>.] - ETA: 0s - loss: 9719639.0000 - mse: 9719638.0000
# Epoch 2: val_loss improved from 10232549.00000 to 10080765.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it1.e002_vl10080765.000.h5
# 97/97 [==============================] - 1s 8ms/step - loss: 9718911.0000 - mse: 9718909.0000 - val_loss: 10080765.0000 - val_mse: 10080763.0000
# Epoch 3/25
# 97/97 [==============================] - ETA: 0s - loss: 9607786.0000 - mse: 9607783.0000
# Epoch 3: val_loss improved from 10080765.00000 to 10041376.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it1.e003_vl10041376.000.h5
# 97/97 [==============================] - 1s 9ms/step - loss: 9607786.0000 - mse: 9607783.0000 - val_loss: 10041376.0000 - val_mse: 10041373.0000
# Epoch 4/25
# 92/97 [===========================>..] - ETA: 0s - loss: 9511217.0000 - mse: 9511215.0000
# Epoch 4: val_loss improved from 10041376.00000 to 10008650.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it1.e004_vl10008650.000.h5
# 97/97 [==============================] - 1s 8ms/step - loss: 9552326.0000 - mse: 9552324.0000 - val_loss: 10008650.0000 - val_mse: 10008647.0000
# Epoch 5/25
# 97/97 [==============================] - ETA: 0s - loss: 9535716.0000 - mse: 9535714.0000
# Epoch 5: val_loss improved from 10008650.00000 to 9984276.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it1.e005_vl9984276.000.h5
# 97/97 [==============================] - 1s 9ms/step - loss: 9535716.0000 - mse: 9535714.0000 - val_loss: 9984276.0000 - val_mse: 9984274.0000
# Epoch 6/25
# 96/97 [============================>.] - ETA: 0s - loss: 9521399.0000 - mse: 9521398.0000
# Epoch 6: val_loss improved from 9984276.00000 to 9977182.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it1.e006_vl9977182.000.h5
# 97/97 [==============================] - 1s 10ms/step - loss: 9513962.0000 - mse: 9513961.0000 - val_loss: 9977182.0000 - val_mse: 9977181.0000
# Epoch 7/25
# 90/97 [==========================>...] - ETA: 0s - loss: 9445634.0000 - mse: 9445633.0000
# Epoch 7: val_loss improved from 9977182.00000 to 9965075.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it1.e007_vl9965075.000.h5
# 97/97 [==============================] - 1s 7ms/step - loss: 9502615.0000 - mse: 9502613.0000 - val_loss: 9965075.0000 - val_mse: 9965073.0000
# Epoch 8/25
# 94/97 [============================>.] - ETA: 0s - loss: 9380738.0000 - mse: 9380737.0000
# Epoch 8: val_loss improved from 9965075.00000 to 9954501.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it1.e008_vl9954501.000.h5
# 97/97 [==============================] - 1s 10ms/step - loss: 9493096.0000 - mse: 9493094.0000 - val_loss: 9954501.0000 - val_mse: 9954500.0000
# Epoch 9/25
# 97/97 [==============================] - ETA: 0s - loss: 9478439.0000 - mse: 9478436.0000
# Epoch 9: val_loss did not improve from 9954501.00000
# 97/97 [==============================] - 1s 8ms/step - loss: 9478439.0000 - mse: 9478436.0000 - val_loss: 9959017.0000 - val_mse: 9959016.0000
# Epoch 10/25
# 90/97 [==========================>...] - ETA: 0s - loss: 9313480.0000 - mse: 9313478.0000
# Epoch 10: val_loss improved from 9954501.00000 to 9945340.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it1.e010_vl9945340.000.h5
# 97/97 [==============================] - 1s 8ms/step - loss: 9472836.0000 - mse: 9472834.0000 - val_loss: 9945340.0000 - val_mse: 9945340.0000
# Epoch 11/25
# 90/97 [==========================>...] - ETA: 0s - loss: 9457603.0000 - mse: 9457602.0000
# Epoch 11: val_loss improved from 9945340.00000 to 9930193.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it1.e011_vl9930193.000.h5
# 97/97 [==============================] - 1s 8ms/step - loss: 9461590.0000 - mse: 9461589.0000 - val_loss: 9930193.0000 - val_mse: 9930191.0000
# Epoch 12/25
# 96/97 [============================>.] - ETA: 0s - loss: 9397817.0000 - mse: 9397815.0000
# Epoch 12: val_loss improved from 9930193.00000 to 9922865.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it1.e012_vl9922865.000.h5
# 97/97 [==============================] - 1s 15ms/step - loss: 9459193.0000 - mse: 9459191.0000 - val_loss: 9922865.0000 - val_mse: 9922863.0000
# Epoch 13/25
# 90/97 [==========================>...] - ETA: 0s - loss: 9500745.0000 - mse: 9500742.0000
# Epoch 13: val_loss improved from 9922865.00000 to 9916483.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it1.e013_vl9916483.000.h5
# 97/97 [==============================] - 1s 8ms/step - loss: 9456991.0000 - mse: 9456988.0000 - val_loss: 9916483.0000 - val_mse: 9916481.0000
# Epoch 14/25
# 92/97 [===========================>..] - ETA: 0s - loss: 9556755.0000 - mse: 9556752.0000
# Epoch 14: val_loss improved from 9916483.00000 to 9903297.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it1.e014_vl9903297.000.h5
# 97/97 [==============================] - 1s 8ms/step - loss: 9439737.0000 - mse: 9439734.0000 - val_loss: 9903297.0000 - val_mse: 9903295.0000
# Epoch 15/25
# 93/97 [===========================>..] - ETA: 0s - loss: 9490759.0000 - mse: 9490755.0000
# Epoch 15: val_loss improved from 9903297.00000 to 9887556.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it1.e015_vl9887556.000.h5
# 97/97 [==============================] - 1s 7ms/step - loss: 9429283.0000 - mse: 9429280.0000 - val_loss: 9887556.0000 - val_mse: 9887554.0000
# Epoch 16/25
# 96/97 [============================>.] - ETA: 0s - loss: 9434251.0000 - mse: 9434249.0000
# Epoch 16: val_loss did not improve from 9887556.00000
# 97/97 [==============================] - 1s 7ms/step - loss: 9423457.0000 - mse: 9423454.0000 - val_loss: 9901338.0000 - val_mse: 9901335.0000
# Epoch 17/25
# 94/97 [============================>.] - ETA: 0s - loss: 9451180.0000 - mse: 9451177.0000
# Epoch 17: val_loss improved from 9887556.00000 to 9881797.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it1.e017_vl9881797.000.h5
# 97/97 [==============================] - 1s 8ms/step - loss: 9408393.0000 - mse: 9408389.0000 - val_loss: 9881797.0000 - val_mse: 9881796.0000
# Epoch 18/25
# 96/97 [============================>.] - ETA: 0s - loss: 9437262.0000 - mse: 9437260.0000
# Epoch 18: val_loss did not improve from 9881797.00000
# 97/97 [==============================] - 1s 8ms/step - loss: 9399306.0000 - mse: 9399304.0000 - val_loss: 9900005.0000 - val_mse: 9900003.0000
# Epoch 19/25
# 90/97 [==========================>...] - ETA: 0s - loss: 9459061.0000 - mse: 9459058.0000
# Epoch 19: val_loss improved from 9881797.00000 to 9871639.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it1.e019_vl9871639.000.h5
# 97/97 [==============================] - 1s 8ms/step - loss: 9395698.0000 - mse: 9395696.0000 - val_loss: 9871639.0000 - val_mse: 9871637.0000
# Epoch 20/25
# 91/97 [===========================>..] - ETA: 0s - loss: 9470064.0000 - mse: 9470060.0000
# Epoch 20: val_loss improved from 9871639.00000 to 9865201.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it1.e020_vl9865201.000.h5
# 97/97 [==============================] - 1s 8ms/step - loss: 9379600.0000 - mse: 9379597.0000 - val_loss: 9865201.0000 - val_mse: 9865198.0000
# Epoch 21/25
# 93/97 [===========================>..] - ETA: 0s - loss: 9399959.0000 - mse: 9399956.0000
# Epoch 21: val_loss improved from 9865201.00000 to 9856034.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it1.e021_vl9856034.000.h5
# 97/97 [==============================] - 1s 8ms/step - loss: 9378509.0000 - mse: 9378506.0000 - val_loss: 9856034.0000 - val_mse: 9856034.0000
# Epoch 22/25
# 97/97 [==============================] - ETA: 0s - loss: 9379484.0000 - mse: 9379482.0000
# Epoch 22: val_loss improved from 9856034.00000 to 9843813.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it1.e022_vl9843813.000.h5
# 97/97 [==============================] - 1s 13ms/step - loss: 9379484.0000 - mse: 9379482.0000 - val_loss: 9843813.0000 - val_mse: 9843812.0000
# Epoch 23/25
# 96/97 [============================>.] - ETA: 0s - loss: 9375539.0000 - mse: 9375536.0000
# Epoch 23: val_loss improved from 9843813.00000 to 9843573.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it1.e023_vl9843573.000.h5
# 97/97 [==============================] - 1s 8ms/step - loss: 9365413.0000 - mse: 9365410.0000 - val_loss: 9843573.0000 - val_mse: 9843571.0000
# Epoch 24/25
# 91/97 [===========================>..] - ETA: 0s - loss: 9401729.0000 - mse: 9401727.0000
# Epoch 24: val_loss improved from 9843573.00000 to 9818676.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it1.e024_vl9818676.000.h5
# 97/97 [==============================] - 1s 8ms/step - loss: 9370742.0000 - mse: 9370740.0000 - val_loss: 9818676.0000 - val_mse: 9818675.0000
# Epoch 25/25
# 90/97 [==========================>...] - ETA: 0s - loss: 9459365.0000 - mse: 9459361.0000
# Epoch 25: val_loss did not improve from 9818676.00000
# 97/97 [==============================] - 1s 8ms/step - loss: 9340592.0000 - mse: 9340587.0000 - val_loss: 9829750.0000 - val_mse: 9829748.0000
# Time elapsed to train: 21.69 s
# Fill in stellar atmospheric parameters ...
# (90000, 3)
# Fill in stellar magnitudes ...
# Empty covariance matrix ...
# Covariance: \delta m ...
# Replace NaN magnitudes ...
# Band 0: 0 of 90000 bad. Replacing with 2612.85376.
# Band 1: 0 of 90000 bad. Replacing with -188.65933.
# Band 2: 0 of 90000 bad. Replacing with -18.31512.
# Band 3: 0 of 90000 bad. Replacing with 6.18737.
# Band 4: 0 of 90000 bad. Replacing with -10.64803.
# Band 5: 0 of 90000 bad. Replacing with -2.49388.
# Band 6: 0 of 90000 bad. Replacing with -4.17958.
# Band 7: 0 of 90000 bad. Replacing with 1.43300.
# Band 8: 0 of 90000 bad. Replacing with -2.10850.
# Band 9: 0 of 90000 bad. Replacing with 0.57402.
# Band 10: 0 of 90000 bad. Replacing with 0.63645.
# Band 11: 0 of 90000 bad. Replacing with 0.40025.
# Band 12: 0 of 90000 bad. Replacing with -0.54446.
# Band 13: 0 of 90000 bad. Replacing with -0.95632.
# Band 14: 0 of 90000 bad. Replacing with 0.17720.
# Band 15: 0 of 90000 bad. Replacing with -0.45189.
# Band 16: 0 of 90000 bad. Replacing with 0.29390.
# Band 17: 0 of 90000 bad. Replacing with 0.11636.
# Band 18: 0 of 90000 bad. Replacing with -0.12801.
# Band 19: 0 of 90000 bad. Replacing with -0.46552.
# Band 20: 0 of 90000 bad. Replacing with -0.26635.
# Band 21: 0 of 90000 bad. Replacing with 0.50923.
# Band 22: 0 of 90000 bad. Replacing with 0.07312.
# Band 23: 0 of 90000 bad. Replacing with 0.03610.
# Band 24: 0 of 90000 bad. Replacing with -0.29431.
# Band 25: 0 of 90000 bad. Replacing with 0.06263.
# Band 26: 0 of 90000 bad. Replacing with 0.01547.
# Band 27: 0 of 90000 bad. Replacing with -0.09176.
# Band 28: 0 of 90000 bad. Replacing with 0.09417.
# Band 29: 0 of 90000 bad. Replacing with -0.14315.
# Band 30: 0 of 90000 bad. Replacing with -0.07631.
# Band 31: 0 of 90000 bad. Replacing with -0.03953.
# Band 32: 0 of 90000 bad. Replacing with -0.01734.
# Band 33: 0 of 90000 bad. Replacing with -0.04669.
# Band 34: 0 of 90000 bad. Replacing with 0.02825.
# Band 35: 0 of 90000 bad. Replacing with -0.01485.
# Band 36: 0 of 90000 bad. Replacing with -0.02775.
# Band 37: 0 of 90000 bad. Replacing with -0.09105.
# Band 38: 0 of 90000 bad. Replacing with 0.21907.
# Band 39: 0 of 90000 bad. Replacing with -0.00444.
# Band 40: 0 of 90000 bad. Replacing with -0.01220.
# Band 41: 0 of 90000 bad. Replacing with -0.06824.
# Band 42: 0 of 90000 bad. Replacing with 0.06865.
# Band 43: 0 of 90000 bad. Replacing with 0.12618.
# Band 44: 0 of 90000 bad. Replacing with -0.01853.
# Band 45: 0 of 90000 bad. Replacing with 0.06758.
# Band 46: 0 of 90000 bad. Replacing with -0.00802.
# Band 47: 0 of 90000 bad. Replacing with -0.01267.
# Band 48: 0 of 90000 bad. Replacing with -0.03340.
# Band 49: 0 of 90000 bad. Replacing with -0.00787.
# Band 50: 0 of 90000 bad. Replacing with 0.05393.
# Band 51: 0 of 90000 bad. Replacing with -0.01438.
# Band 52: 0 of 90000 bad. Replacing with -0.00225.
# Band 53: 0 of 90000 bad. Replacing with -0.00966.
# Band 54: 0 of 90000 bad. Replacing with -0.02330.
# Band 55: 0 of 90000 bad. Replacing with 3036.96289.
# Band 56: 0 of 90000 bad. Replacing with -283.52008.
# Band 57: 0 of 90000 bad. Replacing with -6.74791.
# Band 58: 0 of 90000 bad. Replacing with -0.17156.
# Band 59: 0 of 90000 bad. Replacing with 1.57187.
# Band 60: 0 of 90000 bad. Replacing with -2.52910.
# Band 61: 0 of 90000 bad. Replacing with -1.71546.
# Band 62: 0 of 90000 bad. Replacing with 0.35792.
# Band 63: 0 of 90000 bad. Replacing with -1.25865.
# Band 64: 0 of 90000 bad. Replacing with 0.33275.
# Band 65: 0 of 90000 bad. Replacing with 0.50876.
# Band 66: 0 of 90000 bad. Replacing with 0.17254.
# Band 67: 0 of 90000 bad. Replacing with -0.07569.
# Band 68: 0 of 90000 bad. Replacing with 0.29266.
# Band 69: 0 of 90000 bad. Replacing with -0.30981.
# Band 70: 0 of 90000 bad. Replacing with -0.29009.
# Band 71: 0 of 90000 bad. Replacing with -0.18011.
# Band 72: 0 of 90000 bad. Replacing with 0.22558.
# Band 73: 0 of 90000 bad. Replacing with 0.08554.
# Band 74: 0 of 90000 bad. Replacing with -0.10205.
# Band 75: 0 of 90000 bad. Replacing with 0.42031.
# Band 76: 0 of 90000 bad. Replacing with 0.09891.
# Band 77: 0 of 90000 bad. Replacing with -0.06152.
# Band 78: 0 of 90000 bad. Replacing with 0.10487.
# Band 79: 0 of 90000 bad. Replacing with 0.18044.
# Band 80: 0 of 90000 bad. Replacing with -0.04488.
# Band 81: 0 of 90000 bad. Replacing with -0.27265.
# Band 82: 0 of 90000 bad. Replacing with -0.27430.
# Band 83: 0 of 90000 bad. Replacing with -0.08382.
# Band 84: 0 of 90000 bad. Replacing with 0.11899.
# Band 85: 0 of 90000 bad. Replacing with -0.10379.
# Band 86: 0 of 90000 bad. Replacing with 0.25047.
# Band 87: 0 of 90000 bad. Replacing with 0.03519.
# Band 88: 0 of 90000 bad. Replacing with 0.01375.
# Band 89: 0 of 90000 bad. Replacing with 0.17253.
# Band 90: 0 of 90000 bad. Replacing with 0.08401.
# Band 91: 0 of 90000 bad. Replacing with -0.07828.
# Band 92: 0 of 90000 bad. Replacing with -0.00187.
# Band 93: 0 of 90000 bad. Replacing with 0.03493.
# Band 94: 0 of 90000 bad. Replacing with 0.00578.
# Band 95: 0 of 90000 bad. Replacing with 0.01046.
# Band 96: 0 of 90000 bad. Replacing with -0.14532.
# Band 97: 0 of 90000 bad. Replacing with -0.00097.
# Band 98: 0 of 90000 bad. Replacing with 0.04221.
# Band 99: 0 of 90000 bad. Replacing with -0.02619.
# Band 100: 0 of 90000 bad. Replacing with 0.03100.
# Band 101: 0 of 90000 bad. Replacing with 0.00363.
# Band 102: 0 of 90000 bad. Replacing with 0.02850.
# Band 103: 0 of 90000 bad. Replacing with -0.03859.
# Band 104: 0 of 90000 bad. Replacing with 0.01443.
# Band 105: 0 of 90000 bad. Replacing with 0.01329.
# Band 106: 0 of 90000 bad. Replacing with -0.01029.
# Band 107: 0 of 90000 bad. Replacing with 0.00666.
# Band 108: 0 of 90000 bad. Replacing with 0.00887.
# Band 109: 0 of 90000 bad. Replacing with 0.01525.
# Transform y -> B y ...
# Transform C -> B C B^T ...
# Calculate J = dM/dtheta ...
# ...
# chi^2/dof percentiles:
#   0% : -5.19e+13
#   1% : -1.05e+03
#   10% : 57.6
#   50% : 514
#   90% : 6.39e+03
#   99% : 4.29e+04
#   100% : 1.42e+14
# <chi^2/d.o.f.> = -4.77e+10
# Filter on chi^2/d.o.f. ...
# Filtering 89872 stars (99.9%) based on chi^2/dof > 5.0
# Gather inputs and outputs and return ...
# Fill in stellar atmospheric parameters ...
# (10000, 3)
# Fill in stellar magnitudes ...
# Empty covariance matrix ...
# Covariance: \delta m ...
# Replace NaN magnitudes ...
# Band 0: 0 of 10000 bad. Replacing with 2519.86768.
# Band 1: 0 of 10000 bad. Replacing with -185.48868.
# Band 2: 0 of 10000 bad. Replacing with -17.67404.
# Band 3: 0 of 10000 bad. Replacing with 6.11499.
# Band 4: 0 of 10000 bad. Replacing with -10.40044.
# Band 5: 0 of 10000 bad. Replacing with -2.52704.
# Band 6: 0 of 10000 bad. Replacing with -4.19596.
# Band 7: 0 of 10000 bad. Replacing with 1.46490.
# Band 8: 0 of 10000 bad. Replacing with -2.19853.
# Band 9: 0 of 10000 bad. Replacing with 0.56087.
# Band 10: 0 of 10000 bad. Replacing with 0.62344.
# Band 11: 0 of 10000 bad. Replacing with 0.35939.
# Band 12: 0 of 10000 bad. Replacing with -0.53096.
# Band 13: 0 of 10000 bad. Replacing with -0.92730.
# Band 14: 0 of 10000 bad. Replacing with 0.14079.
# Band 15: 0 of 10000 bad. Replacing with -0.45577.
# Band 16: 0 of 10000 bad. Replacing with 0.28794.
# Band 17: 0 of 10000 bad. Replacing with 0.12051.
# Band 18: 0 of 10000 bad. Replacing with -0.13238.
# Band 19: 0 of 10000 bad. Replacing with -0.44958.
# Band 20: 0 of 10000 bad. Replacing with -0.26492.
# Band 21: 0 of 10000 bad. Replacing with 0.49535.
# Band 22: 0 of 10000 bad. Replacing with 0.08438.
# Band 23: 0 of 10000 bad. Replacing with 0.03175.
# Band 24: 0 of 10000 bad. Replacing with -0.29904.
# Band 25: 0 of 10000 bad. Replacing with 0.05646.
# Band 26: 0 of 10000 bad. Replacing with 0.00629.
# Band 27: 0 of 10000 bad. Replacing with -0.08972.
# Band 28: 0 of 10000 bad. Replacing with 0.08224.
# Band 29: 0 of 10000 bad. Replacing with -0.13855.
# Band 30: 0 of 10000 bad. Replacing with -0.07389.
# Band 31: 0 of 10000 bad. Replacing with -0.02651.
# Band 32: 0 of 10000 bad. Replacing with -0.03307.
# Band 33: 0 of 10000 bad. Replacing with -0.03489.
# Band 34: 0 of 10000 bad. Replacing with 0.03333.
# Band 35: 0 of 10000 bad. Replacing with -0.02749.
# Band 36: 0 of 10000 bad. Replacing with -0.01370.
# Band 37: 0 of 10000 bad. Replacing with -0.08412.
# Band 38: 0 of 10000 bad. Replacing with 0.21914.
# Band 39: 0 of 10000 bad. Replacing with -0.00405.
# Band 40: 0 of 10000 bad. Replacing with -0.00845.
# Band 41: 0 of 10000 bad. Replacing with -0.06751.
# Band 42: 0 of 10000 bad. Replacing with 0.06643.
# Band 43: 0 of 10000 bad. Replacing with 0.12424.
# Band 44: 0 of 10000 bad. Replacing with -0.01247.
# Band 45: 0 of 10000 bad. Replacing with 0.07829.
# Band 46: 0 of 10000 bad. Replacing with -0.01485.
# Band 47: 0 of 10000 bad. Replacing with -0.01484.
# Band 48: 0 of 10000 bad. Replacing with -0.02285.
# Band 49: 0 of 10000 bad. Replacing with -0.00365.
# Band 50: 0 of 10000 bad. Replacing with 0.05589.
# Band 51: 0 of 10000 bad. Replacing with -0.01692.
# Band 52: 0 of 10000 bad. Replacing with -0.00244.
# Band 53: 0 of 10000 bad. Replacing with -0.00817.
# Band 54: 0 of 10000 bad. Replacing with -0.02454.
# Band 55: 0 of 10000 bad. Replacing with 2929.80273.
# Band 56: 0 of 10000 bad. Replacing with -271.45276.
# Band 57: 0 of 10000 bad. Replacing with -6.83614.
# Band 58: 0 of 10000 bad. Replacing with -0.25828.
# Band 59: 0 of 10000 bad. Replacing with 1.57831.
# Band 60: 0 of 10000 bad. Replacing with -2.45279.
# Band 61: 0 of 10000 bad. Replacing with -1.61302.
# Band 62: 0 of 10000 bad. Replacing with 0.35328.
# Band 63: 0 of 10000 bad. Replacing with -1.22888.
# Band 64: 0 of 10000 bad. Replacing with 0.36328.
# Band 65: 0 of 10000 bad. Replacing with 0.51836.
# Band 66: 0 of 10000 bad. Replacing with 0.17048.
# Band 67: 0 of 10000 bad. Replacing with -0.10558.
# Band 68: 0 of 10000 bad. Replacing with 0.30792.
# Band 69: 0 of 10000 bad. Replacing with -0.30396.
# Band 70: 0 of 10000 bad. Replacing with -0.28569.
# Band 71: 0 of 10000 bad. Replacing with -0.17943.
# Band 72: 0 of 10000 bad. Replacing with 0.23553.
# Band 73: 0 of 10000 bad. Replacing with 0.09229.
# Band 74: 0 of 10000 bad. Replacing with -0.10631.
# Band 75: 0 of 10000 bad. Replacing with 0.43443.
# Band 76: 0 of 10000 bad. Replacing with 0.09967.
# Band 77: 0 of 10000 bad. Replacing with -0.07085.
# Band 78: 0 of 10000 bad. Replacing with 0.08789.
# Band 79: 0 of 10000 bad. Replacing with 0.16128.
# Band 80: 0 of 10000 bad. Replacing with -0.04057.
# Band 81: 0 of 10000 bad. Replacing with -0.28594.
# Band 82: 0 of 10000 bad. Replacing with -0.27260.
# Band 83: 0 of 10000 bad. Replacing with -0.08840.
# Band 84: 0 of 10000 bad. Replacing with 0.12088.
# Band 85: 0 of 10000 bad. Replacing with -0.08976.
# Band 86: 0 of 10000 bad. Replacing with 0.23824.
# Band 87: 0 of 10000 bad. Replacing with 0.03630.
# Band 88: 0 of 10000 bad. Replacing with 0.02519.
# Band 89: 0 of 10000 bad. Replacing with 0.17770.
# Band 90: 0 of 10000 bad. Replacing with 0.09419.
# Band 91: 0 of 10000 bad. Replacing with -0.07830.
# Band 92: 0 of 10000 bad. Replacing with -0.00332.
# Band 93: 0 of 10000 bad. Replacing with 0.03753.
# Band 94: 0 of 10000 bad. Replacing with 0.00923.
# Band 95: 0 of 10000 bad. Replacing with 0.01108.
# Band 96: 0 of 10000 bad. Replacing with -0.14352.
# Band 97: 0 of 10000 bad. Replacing with -0.00540.
# Band 98: 0 of 10000 bad. Replacing with 0.04046.
# Band 99: 0 of 10000 bad. Replacing with -0.02886.
# Band 100: 0 of 10000 bad. Replacing with 0.03466.
# Band 101: 0 of 10000 bad. Replacing with 0.01331.
# Band 102: 0 of 10000 bad. Replacing with 0.02945.
# Band 103: 0 of 10000 bad. Replacing with -0.04120.
# Band 104: 0 of 10000 bad. Replacing with 0.01455.
# Band 105: 0 of 10000 bad. Replacing with 0.01535.
# Band 106: 0 of 10000 bad. Replacing with -0.01361.
# Band 107: 0 of 10000 bad. Replacing with 0.01189.
# Band 108: 0 of 10000 bad. Replacing with 0.00966.
# Band 109: 0 of 10000 bad. Replacing with 0.01380.
# Transform y -> B y ...
# Transform C -> B C B^T ...
# Calculate J = dM/dtheta ...
# Covariance: J C_theta J^T ...
# J_M.shape = (10000, 110, 3)
# cov_x.shape = (10000, 3, 3)
# cov_y.shape = (10000, 110, 110)
# Invert C_y matrices ...
# chisq = [193804.25     5543.703   73542.5    ...  84478.     231358.
#   -7514.8438]
# Calculate d.o.f. of each star ...
# Calculate chi^2/d.o.f. for each star ...
# chi^2/dof percentiles:
#   0% : -2.97e+12
#   1% : -851
#   10% : 56.7
#   50% : 513
#   90% : 6.02e+03
#   99% : 3.97e+04
#   100% : 8.69e+06
# <chi^2/d.o.f.> = -1.54e+10
# Gather inputs and outputs and return ...
# Time elapsed to prepare data: 488.40 s
# learning rate = 0.00027323723770678043
# setting learning rate to 0.00022370771856165591
# Iteration 20 of 20.
# Epoch 1/25
# 1/1 [==============================] - ETA: 0s - loss: 1505936.1250 - mse: 1505932.8750
# Epoch 1: val_loss improved from inf to 1787013.50000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it19.e001_vl1787013.500.h5
# 1/1 [==============================] - 1s 825ms/step - loss: 1505936.1250 - mse: 1505932.8750 - val_loss: 1787013.5000 - val_mse: 1787010.2500
# Epoch 2/25
# 1/1 [==============================] - ETA: 0s - loss: 1506714.7500 - mse: 1506711.5000
# Epoch 2: val_loss did not improve from 1787013.50000
# 1/1 [==============================] - 0s 43ms/step - loss: 1506714.7500 - mse: 1506711.5000 - val_loss: 1788201.2500 - val_mse: 1788198.0000
# Epoch 3/25
# 1/1 [==============================] - ETA: 0s - loss: 1506482.3750 - mse: 1506479.2500
# Epoch 3: val_loss did not improve from 1787013.50000
# 1/1 [==============================] - 0s 41ms/step - loss: 1506482.3750 - mse: 1506479.2500 - val_loss: 1788225.2500 - val_mse: 1788222.0000
# Epoch 4/25
# 1/1 [==============================] - ETA: 0s - loss: 1505359.2500 - mse: 1505356.0000
# Epoch 4: val_loss did not improve from 1787013.50000
# 1/1 [==============================] - 0s 40ms/step - loss: 1505359.2500 - mse: 1505356.0000 - val_loss: 1787222.7500 - val_mse: 1787219.5000
# Epoch 5/25
# 1/1 [==============================] - ETA: 0s - loss: 1503467.6250 - mse: 1503464.3750
# Epoch 5: val_loss improved from 1787013.50000 to 1785329.75000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it19.e005_vl1785329.750.h5
# 1/1 [==============================] - 0s 71ms/step - loss: 1503467.6250 - mse: 1503464.3750 - val_loss: 1785329.7500 - val_mse: 1785326.5000
# Epoch 6/25
# 1/1 [==============================] - ETA: 0s - loss: 1500929.8750 - mse: 1500926.6250
# Epoch 6: val_loss improved from 1785329.75000 to 1782678.50000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it19.e006_vl1782678.500.h5
# 1/1 [==============================] - 0s 77ms/step - loss: 1500929.8750 - mse: 1500926.6250 - val_loss: 1782678.5000 - val_mse: 1782675.2500
# Epoch 7/25
# 1/1 [==============================] - ETA: 0s - loss: 1497863.8750 - mse: 1497860.5000
# Epoch 7: val_loss improved from 1782678.50000 to 1779396.37500, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it19.e007_vl1779396.375.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 1497863.8750 - mse: 1497860.5000 - val_loss: 1779396.3750 - val_mse: 1779393.1250
# Epoch 8/25
# 1/1 [==============================] - ETA: 0s - loss: 1494380.0000 - mse: 1494376.7500
# Epoch 8: val_loss improved from 1779396.37500 to 1775601.75000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it19.e008_vl1775601.750.h5
# 1/1 [==============================] - 0s 75ms/step - loss: 1494380.0000 - mse: 1494376.7500 - val_loss: 1775601.7500 - val_mse: 1775598.5000
# Epoch 9/25
# 1/1 [==============================] - ETA: 0s - loss: 1490578.7500 - mse: 1490575.5000
# Epoch 9: val_loss improved from 1775601.75000 to 1771403.25000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it19.e009_vl1771403.250.h5
# 1/1 [==============================] - 0s 105ms/step - loss: 1490578.7500 - mse: 1490575.5000 - val_loss: 1771403.2500 - val_mse: 1771400.0000
# Epoch 10/25
# 1/1 [==============================] - ETA: 0s - loss: 1486548.8750 - mse: 1486545.6250
# Epoch 10: val_loss improved from 1771403.25000 to 1766901.25000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it19.e010_vl1766901.250.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 1486548.8750 - mse: 1486545.6250 - val_loss: 1766901.2500 - val_mse: 1766898.0000
# Epoch 11/25
# 1/1 [==============================] - ETA: 0s - loss: 1482367.2500 - mse: 1482364.1250
# Epoch 11: val_loss improved from 1766901.25000 to 1762183.25000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it19.e011_vl1762183.250.h5
# 1/1 [==============================] - 0s 79ms/step - loss: 1482367.2500 - mse: 1482364.1250 - val_loss: 1762183.2500 - val_mse: 1762180.0000
# Epoch 12/25
# 1/1 [==============================] - ETA: 0s - loss: 1478100.8750 - mse: 1478097.6250
# Epoch 12: val_loss improved from 1762183.25000 to 1757328.12500, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it19.e012_vl1757328.125.h5
# 1/1 [==============================] - 0s 80ms/step - loss: 1478100.8750 - mse: 1478097.6250 - val_loss: 1757328.1250 - val_mse: 1757324.8750
# Epoch 13/25
# 1/1 [==============================] - ETA: 0s - loss: 1473803.6250 - mse: 1473800.3750
# Epoch 13: val_loss improved from 1757328.12500 to 1752405.75000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it19.e013_vl1752405.750.h5
# 1/1 [==============================] - 0s 79ms/step - loss: 1473803.6250 - mse: 1473800.3750 - val_loss: 1752405.7500 - val_mse: 1752402.5000
# Epoch 14/25
# 1/1 [==============================] - ETA: 0s - loss: 1469521.6250 - mse: 1469518.2500
# Epoch 14: val_loss improved from 1752405.75000 to 1747476.62500, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it19.e014_vl1747476.625.h5
# 1/1 [==============================] - 0s 75ms/step - loss: 1469521.6250 - mse: 1469518.2500 - val_loss: 1747476.6250 - val_mse: 1747473.3750
# Epoch 15/25
# 1/1 [==============================] - ETA: 0s - loss: 1465292.1250 - mse: 1465288.8750
# Epoch 15: val_loss improved from 1747476.62500 to 1742593.25000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it19.e015_vl1742593.250.h5
# 1/1 [==============================] - 0s 71ms/step - loss: 1465292.1250 - mse: 1465288.8750 - val_loss: 1742593.2500 - val_mse: 1742590.0000
# Epoch 16/25
# 1/1 [==============================] - ETA: 0s - loss: 1461146.3750 - mse: 1461143.1250
# Epoch 16: val_loss improved from 1742593.25000 to 1737800.62500, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it19.e016_vl1737800.625.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 1461146.3750 - mse: 1461143.1250 - val_loss: 1737800.6250 - val_mse: 1737797.3750
# Epoch 17/25
# 1/1 [==============================] - ETA: 0s - loss: 1457108.2500 - mse: 1457105.0000
# Epoch 17: val_loss improved from 1737800.62500 to 1733136.37500, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it19.e017_vl1733136.375.h5
# 1/1 [==============================] - 0s 77ms/step - loss: 1457108.2500 - mse: 1457105.0000 - val_loss: 1733136.3750 - val_mse: 1733133.1250
# Epoch 18/25
# 1/1 [==============================] - ETA: 0s - loss: 1453197.3750 - mse: 1453194.1250
# Epoch 18: val_loss improved from 1733136.37500 to 1728632.12500, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it19.e018_vl1728632.125.h5
# 1/1 [==============================] - 0s 74ms/step - loss: 1453197.3750 - mse: 1453194.1250 - val_loss: 1728632.1250 - val_mse: 1728628.8750
# Epoch 19/25
# 1/1 [==============================] - ETA: 0s - loss: 1449429.3750 - mse: 1449426.1250
# Epoch 19: val_loss improved from 1728632.12500 to 1724314.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it19.e019_vl1724314.000.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 1449429.3750 - mse: 1449426.1250 - val_loss: 1724314.0000 - val_mse: 1724310.7500
# Epoch 20/25
# 1/1 [==============================] - ETA: 0s - loss: 1445814.0000 - mse: 1445810.7500
# Epoch 20: val_loss improved from 1724314.00000 to 1720201.00000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it19.e020_vl1720201.000.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 1445814.0000 - mse: 1445810.7500 - val_loss: 1720201.0000 - val_mse: 1720197.7500
# Epoch 21/25
# 1/1 [==============================] - ETA: 0s - loss: 1442358.2500 - mse: 1442355.0000
# Epoch 21: val_loss improved from 1720201.00000 to 1716308.75000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it19.e021_vl1716308.750.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 1442358.2500 - mse: 1442355.0000 - val_loss: 1716308.7500 - val_mse: 1716305.5000
# Epoch 22/25
# 1/1 [==============================] - ETA: 0s - loss: 1439066.2500 - mse: 1439063.0000
# Epoch 22: val_loss improved from 1716308.75000 to 1712646.62500, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it19.e022_vl1712646.625.h5
# 1/1 [==============================] - 0s 91ms/step - loss: 1439066.2500 - mse: 1439063.0000 - val_loss: 1712646.6250 - val_mse: 1712643.3750
# Epoch 23/25
# 1/1 [==============================] - ETA: 0s - loss: 1435937.3750 - mse: 1435934.1250
# Epoch 23: val_loss improved from 1712646.62500 to 1709221.50000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it19.e023_vl1709221.500.h5
# 1/1 [==============================] - 0s 73ms/step - loss: 1435937.3750 - mse: 1435934.1250 - val_loss: 1709221.5000 - val_mse: 1709218.2500
# Epoch 24/25
# 1/1 [==============================] - ETA: 0s - loss: 1432969.6250 - mse: 1432966.3750
# Epoch 24: val_loss improved from 1709221.50000 to 1706036.62500, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it19.e024_vl1706036.625.h5
# 1/1 [==============================] - 0s 75ms/step - loss: 1432969.6250 - mse: 1432966.3750 - val_loss: 1706036.6250 - val_mse: 1706033.3750
# Epoch 25/25
# 1/1 [==============================] - ETA: 0s - loss: 1430158.2500 - mse: 1430155.0000
# Epoch 25: val_loss improved from 1706036.62500 to 1703093.50000, saving model to checkpoints/xp_l2_mse_lr02_4hidden_it19.e025_vl1703093.500.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 1430158.2500 - mse: 1430155.0000 - val_loss: 1703093.5000 - val_mse: 1703090.2500
# Time elapsed to train: 2.80 s

# %%
# print('Updating covariances and reddening estimates of test dataset ...')
# t0 = time()
# io_test = get_inputs_outputs(
#     d_test,
#     pretrained_model=nn_model,
#     recalc_reddening=True
# )
# t1 = time()
# print(f'Time elapsed to update covariances and reddenings: {t1-t0:.2f} s')

# %%
# Evaluate performance on (train, validation and test sets)
loss = {}
for n,io_eval in (('test',io_test), ('train',io_train)):
    loss[n] = evaluate_model(
        nn_model,
        io_eval,
        batch_size=batch_size,
        rchisq_max=rchisq_max[-1]
    )
    print(f'{n} loss: {loss[n]}')
fname = 'loss/loss_{:s}_{:d}hidden_it{:d}.json'.format(
    nn_name, n_hidden, n_iterations-1
)
with open(fname, 'w') as f:
    json.dump(loss, f, indent=2, sort_keys=True)

# n_hidden = 2
fname = 'predictions/predictions_{:s}_{:d}hidden_it{:d}.h5'.format(
    nn_name, n_hidden, n_iterations-1
)
save_predictions(fname, nn_model, d_test, io_test)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [20], in <cell line: 3>()
#       2 loss = {}
#       3 for n,io_eval in (('test',io_test), ('train',io_train)):
# ----> 4     loss[n] = evaluate_model(
#       5         nn_model,
#       6         io_eval,
#       7         batch_size=batch_size,
#       8         rchisq_max=rchisq_max[-1]
#       9     )
#      10     print(f'{n} loss: {loss[n]}')
#      11 fname = 'loss/loss_{:s}_{:d}hidden_it{:d}.json'.format(
#      12     nn_name, n_hidden, n_iterations-1
#      13 )
#
# Input In [9], in evaluate_model(nn_model, io_eval, batch_size, rchisq_max)
#      19 outputs = io_eval['y']
#      21 if rchisq_max is not None:
# ---> 22     idx = (io_eval['rchisq'] < rchisq_max)
#      23     inputs = inputs[idx]
#      24     outputs = outputs[idx]
#
# KeyError: 'rchisq'

# %%
print('Saving covariance components for small subset of test dataset ...')
# Fix random seed (same subset every run)
np.random.seed(3)
idx = np.arange(d_test.size)
np.random.shuffle(idx)
idx = idx[:1000]
d_comp = d_test[idx]
io_comp = get_inputs_outputs(
    d_comp,
    pretrained_model=nn_model,
    recalc_reddening=True,
    return_cov_components=True
)
fname = 'predictions/predictions_{:s}_{:d}hidden_it{:d}_comp.h5'.format(
    nn_name, n_hidden, n_iterations-1
)
save_predictions(fname, nn_model, d_comp, io_comp)
# Out:
# Saving covariance components for small subset of test dataset ...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [21], in <cell line: 7>()
#       5 np.random.shuffle(idx)
#       6 idx = idx[:1000]
# ----> 7 d_comp = d_test[idx]
#       8 io_comp = get_inputs_outputs(
#       9     d_comp,
#      10     pretrained_model=nn_model,
#      11     recalc_reddening=True,
#      12     return_cov_components=True
#      13 )
#      14 fname = 'predictions/predictions_{:s}_{:d}hidden_it{:d}_comp.h5'.format(
#      15     nn_name, n_hidden, n_iterations-1
#      16 )
#
# IndexError: index 5876 is out of bounds for axis 0 with size 1

# %%
print('Saving data and reddening estimates of subset of test dataset ...')
np.random.seed(5)
idx = np.arange(d_test.size)
np.random.shuffle(idx)
idx = idx[:10000]
d_small = d_test[idx]
r_fit_small = io_test['r'][idx]
r_var_small = io_test['r_var'][idx]
fname = 'test_data_small/test_data_small_{:s}_{:d}hidden.h5'.format(
    nn_name, n_hidden
)
# Out:
# Saving data and reddening estimates of subset of test dataset ...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [22], in <cell line: 6>()
#       4 np.random.shuffle(idx)
#       5 idx = idx[:10000]
# ----> 6 d_small = d_test[idx]
#       7 r_fit_small = io_test['r'][idx]
#       8 r_var_small = io_test['r_var'][idx]
#
# IndexError: index 7054 is out of bounds for axis 0 with size 1

# %%
print(f'Saving subset to {fname} ...')
with h5py.File(fname, 'w') as f:
    dset = f.create_dataset(
        'data',
        data=d_small,
        chunks=True,
        compression='gzip',
        compression_opts=3
    )
    for key in d_attrs:
        dset.attrs[key] = d_attrs[key]

    # # Store updated reddening estimates
    # dset = f.create_dataset(
    #     'r_fit',
    #     data=r_fit_small,
    #     chunks=True,
    #     compression='gzip',
    #     compression_opts=3
    # )
    # dset = f.create_dataset(
    #     'r_var',
    #     data=r_var_small,
    #     chunks=True,
    #     compression='gzip',
    #     compression_opts=3
    # )
# Out:
# Saving subset to /arc/home/aydanmckay/ml/network/datasets/dr3datasmall.h5 ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 2>()
#       1 print(f'Saving subset to {fname} ...')
#       2 with h5py.File(fname, 'w') as f:
#       3     dset = f.create_dataset(
#       4         'data',
# ----> 5         data=d_small,
#       6         chunks=True,
#       7         compression='gzip',
#       8         compression_opts=3
#       9     )
#      10     for key in d_attrs:
#      11         dset.attrs[key] = d_attrs[key]
#
# NameError: name 'd_small' is not defined
